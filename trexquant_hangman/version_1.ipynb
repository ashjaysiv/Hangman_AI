# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
import torch.optim as optim

# %%
import torchtext.vocab as vocab

# %%
glove = vocab.GloVe(name='6B', dim=100)
alphabet = 'abcdefghijklmnopqrstuvwxyz'
letter_vocab = {letter: idx for idx, letter in enumerate(alphabet)}

# %%
def letter_to_embedding(letter):
    if letter in letter_vocab:
        index = letter_vocab[letter]
    else:
        # Handle unknown letters with a special token or random embedding
        index = letter_vocab['<UNK>']
    return glove.vectors[index]

# %%
input_letter = 'a'
embedding = letter_to_embedding(input_letter)
embedding.shape
# Out:
# torch.Size([100])

# %%
filename = "./words_250000_train.txt"

word_dict = []
with open(filename, 'r') as f:
    for line in f:
        word = line.split()[0]
        if word.isalpha():
            word_dict.append(word)

words = list(np.random.permutation(list(word_dict)))

# %%
len(words)
# Out:
# 227300

# %%
train_val_split_idx = int(len(words) * 0.8)

MAX_NUM_INPUTS = max([len(i) for i in words[:train_val_split_idx]])
EPOCH_SIZE = train_val_split_idx
NUM_EPOCHS = 100
BATCH_SIZE = np.array([len(i) for i in words[:train_val_split_idx]]).mean() #?

# %%
MAX_NUM_INPUTS, EPOCH_SIZE, NUM_EPOCHS, BATCH_SIZE
# Out:
# (29, 181840, 100, 9.35000549934008)

# %%
class HangmanPlayer:
    def __init__(self, word, model, lives=6):
        self.original_word = word
        self.full_word = [ord(i)-97 for i in word]
        self.embedded_word = [list(letter_to_embedding(letter)) for letter in word]
        self.embedded_word = torch.tensor(self.embedded_word)
        self.letters_guessed = set([])
        self.letters_remaining = set(self.full_word)
        self.lives_left = lives
        self.obscured_words_seen = []
        self.letters_previously_guessed = []
        self.guesses = []
        self.correct_responses = []
        self.z = model
        return
    
    def encode_obscured_word(self):
        word = [i if i in self.letters_guessed else 26 for i in self.full_word]
        obscured_word = np.zeros((len(word), 100), dtype=np.float32)
        
        for i, j in enumerate(word):
            if j != 26:
                obscured_word[i] = list(letter_to_embedding(chr(97+j)))
                
        return(torch.tensor(obscured_word))
    
    def encode_guess(self, guess):
        encoded_guess = np.zeros(26, dtype=np.float32)
        encoded_guess[guess] = 1
        return(encoded_guess)

    def encode_previous_guesses(self):
        # Create a 1 x 26 vector where 1s indicate that the letter was previously guessed
        guess = np.zeros(26, dtype=np.float32)
        for i in self.letters_guessed:
            guess[i] = 1
        return(guess)
    
    def encode_correct_responses(self):
        # To be used with cross_entropy_with_softmax, this vector must be normalized
        response = np.zeros(26, dtype=np.float32)
        for i in self.letters_remaining:
            response[i] = 1.0
        response /= response.sum()
        return(response)

     
    
    def store_guess_and_result(self, guess):
        # Record what the model saw as input: an obscured word and a list of previously-guessed letters
        self.obscured_words_seen.append(self.encode_obscured_word())
        self.letters_previously_guessed.append(self.encode_previous_guesses())
        
        # Record the letter that the model guessed, and add that guess to the list of previous guesses
        self.guesses.append(guess)
        self.letters_guessed.add(int(guess))
        # print(guess)
        # Store the "correct responses"
        correct_responses = self.encode_correct_responses()
        self.correct_responses.append(correct_responses)
        
        # Determine an appropriate reward, and reduce # of lives left if appropriate
        if int(guess) in self.letters_remaining:
            self.letters_remaining.remove(int(guess))
        
        if self.correct_responses[-1][guess] < 0.00001:
            self.lives_left -= 1
        return
                
    def run(self):
        # Play a game until we run out of lives or letters
        while (self.lives_left > 0) and (len(self.letters_remaining) > 0):
            self.encoded_obscured_word = torch.tensor(self.encode_obscured_word())
            self.encoded_obscured_word = torch.reshape(self.encoded_obscured_word, [1, self.encoded_obscured_word.shape[0], self.encoded_obscured_word.shape[1]] )
            
            self.encoded_previous_guesses = torch.tensor(self.encode_previous_guesses())
            self.encoded_previous_guesses = torch.reshape(self.encoded_previous_guesses, [1, self.encoded_previous_guesses.shape[0]])
            
            output = torch.squeeze(self.z(self.encoded_obscured_word, self.encoded_previous_guesses))
            guess = torch.argmax(output)
            attempt = 2
            while int(guess) in self.letters_guessed:
                guess = torch.topk(output, k=attempt).indices[attempt-1]
                attempt += 1
            self.store_guess_and_result(guess)

        b = torch.tensor(self.letters_previously_guessed)
        c = torch.tensor(self.correct_responses)
        # Return the observations for use in training (both inputs, predictions, and losses)
        return torch.stack(self.obscured_words_seen), torch.tensor(self.letters_previously_guessed), torch.tensor(self.correct_responses)

# %%
class LSTMNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMNet, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.fc = nn.Linear(hidden_size + output_size, output_size)
        

    def forward(self, input_obscured_word_seen, input_letters_guessed_previously):
        
        lstm_outputs, _ = self.lstm(input_obscured_word_seen)
        final_lstm_output = lstm_outputs[:, -1, : ]

        combined_input = torch.cat((final_lstm_output, input_letters_guessed_previously), dim=1)
        output = self.fc(combined_input)
        return output

# %%
lstm = LSTMNet(100 ,MAX_NUM_INPUTS, 26)

# %%
learning_rate = 0.001
momentum_time_constant = BATCH_SIZE / -np.log(0.9)

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(lstm.parameters(), lr=learning_rate, momentum=momentum_time_constant)

# %%
total_samples = 0

for epoch in range(NUM_EPOCHS):
    i = 0
    while total_samples < (epoch+1) * EPOCH_SIZE:
        torch.autograd.set_detect_anomaly(True)
        
        optimizer.zero_grad()

        word = words[i]
        i += 1

        other_player = HangmanPlayer(word, lstm)
        words_seen, previous_letters, correct_responses = other_player.run()

        # output = lstm(words_seen,  previous_letters)
       
        
        optimizer.zero_grad()
        words_seen.shape
        z = lstm(words_seen, previous_letters)
        
        loss = F.cross_entropy(z, correct_responses)
        
        loss.backward()

        optimizer.step()
        if total_samples % 20000 == 0:
            print(loss)
       
    print("_________________________________________________________")
    print(epoch)
    print("_________________________________________________________")
# Out:
# /tmp/ipykernel_1242887/3407111068.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.encoded_obscured_word = torch.tensor(self.encode_obscured_word())
# tensor(3.2571, grad_fn=<DivBackward1>)
# tensor(3.3926, grad_fn=<DivBackward1>)
# tensor(3.2994, grad_fn=<DivBackward1>)
# tensor(3.3402, grad_fn=<DivBackward1>)
# tensor(3.3450, grad_fn=<DivBackward1>)
# tensor(3.3749, grad_fn=<DivBackward1>)
# tensor(3.3274, grad_fn=<DivBackward1>)
# tensor(3.3137, grad_fn=<DivBackward1>)
# tensor(3.3531, grad_fn=<DivBackward1>)
# tensor(3.3300, grad_fn=<DivBackward1>)
# tensor(3.3473, grad_fn=<DivBackward1>)
# tensor(3.3741, grad_fn=<DivBackward1>)
# tensor(3.3190, grad_fn=<DivBackward1>)
# tensor(3.3184, grad_fn=<DivBackward1>)
# tensor(3.3436, grad_fn=<DivBackward1>)
# tensor(3.3650, grad_fn=<DivBackward1>)
# tensor(3.3654, grad_fn=<DivBackward1>)
# tensor(3.3476, grad_fn=<DivBackward1>)
# tensor(3.3338, grad_fn=<DivBackward1>)
# tensor(3.3291, grad_fn=<DivBackward1>)
# tensor(3.3119, grad_fn=<DivBackward1>)
# tensor(3.3288, grad_fn=<DivBackward1>)
# tensor(3.3747, grad_fn=<DivBackward1>)
# tensor(3.3360, grad_fn=<DivBackward1>)
# tensor(3.4102, grad_fn=<DivBackward1>)
# tensor(3.3286, grad_fn=<DivBackward1>)
# tensor(3.3290, grad_fn=<DivBackward1>)
# tensor(3.3517, grad_fn=<DivBackward1>)
# tensor(3.3792, grad_fn=<DivBackward1>)
# tensor(3.4076, grad_fn=<DivBackward1>)
# tensor(3.4196, grad_fn=<DivBackward1>)
# tensor(3.3622, grad_fn=<DivBackward1>)
# tensor(3.3401, grad_fn=<DivBackward1>)
# tensor(3.3094, grad_fn=<DivBackward1>)
# tensor(3.3787, grad_fn=<DivBackward1>)
# tensor(3.3906, grad_fn=<DivBackward1>)
# tensor(3.3434, grad_fn=<DivBackward1>)
# tensor(3.2649, grad_fn=<DivBackward1>)
# tensor(3.4180, grad_fn=<DivBackward1>)
# tensor(3.3258, grad_fn=<DivBackward1>)
# tensor(3.3635, grad_fn=<DivBackward1>)
# tensor(3.2726, grad_fn=<DivBackward1>)
# tensor(3.2775, grad_fn=<DivBackward1>)
# tensor(3.3573, grad_fn=<DivBackward1>)
# tensor(3.3514, grad_fn=<DivBackward1>)
# tensor(3.3657, grad_fn=<DivBackward1>)
# tensor(3.3693, grad_fn=<DivBackward1>)
# tensor(3.3421, grad_fn=<DivBackward1>)
# tensor(3.3546, grad_fn=<DivBackward1>)
# tensor(3.3463, grad_fn=<DivBackward1>)
# tensor(3.2969, grad_fn=<DivBackward1>)
# tensor(3.3736, grad_fn=<DivBackward1>)
# tensor(3.3082, grad_fn=<DivBackward1>)
# tensor(3.3469, grad_fn=<DivBackward1>)
# tensor(3.3076, grad_fn=<DivBackward1>)
# tensor(3.2845, grad_fn=<DivBackward1>)
# tensor(3.3757, grad_fn=<DivBackward1>)
# tensor(3.3899, grad_fn=<DivBackward1>)
# tensor(3.3157, grad_fn=<DivBackward1>)
# tensor(3.3018, grad_fn=<DivBackward1>)
# tensor(3.3248, grad_fn=<DivBackward1>)
# tensor(3.3969, grad_fn=<DivBackward1>)
# tensor(3.3731, grad_fn=<DivBackward1>)
# tensor(3.3418, grad_fn=<DivBackward1>)
# tensor(3.3703, grad_fn=<DivBackward1>)
# tensor(3.3398, grad_fn=<DivBackward1>)
# tensor(3.3861, grad_fn=<DivBackward1>)
# tensor(3.2650, grad_fn=<DivBackward1>)
# tensor(3.3450, grad_fn=<DivBackward1>)
# tensor(3.3824, grad_fn=<DivBackward1>)
# tensor(3.3516, grad_fn=<DivBackward1>)
# tensor(3.3218, grad_fn=<DivBackward1>)
# tensor(3.3315, grad_fn=<DivBackward1>)
# tensor(3.3004, grad_fn=<DivBackward1>)
# tensor(3.3290, grad_fn=<DivBackward1>)
# tensor(3.3158, grad_fn=<DivBackward1>)
# tensor(3.3984, grad_fn=<DivBackward1>)
# tensor(3.3329, grad_fn=<DivBackward1>)
# tensor(3.3058, grad_fn=<DivBackward1>)
# tensor(3.3383, grad_fn=<DivBackward1>)
# tensor(3.3231, grad_fn=<DivBackward1>)
# tensor(3.2900, grad_fn=<DivBackward1>)
# tensor(3.3580, grad_fn=<DivBackward1>)
# tensor(3.3920, grad_fn=<DivBackward1>)
# tensor(3.4000, grad_fn=<DivBackward1>)
# tensor(3.3380, grad_fn=<DivBackward1>)
# tensor(3.3144, grad_fn=<DivBackward1>)
# tensor(3.3699, grad_fn=<DivBackward1>)
# tensor(3.3403, grad_fn=<DivBackward1>)
# tensor(3.3260, grad_fn=<DivBackward1>)
# tensor(3.3500, grad_fn=<DivBackward1>)
# tensor(3.3399, grad_fn=<DivBackward1>)
# tensor(3.2792, grad_fn=<DivBackward1>)
# tensor(3.3235, grad_fn=<DivBackward1>)
# tensor(3.3227, grad_fn=<DivBackward1>)
# tensor(3.4036, grad_fn=<DivBackward1>)
# tensor(3.3059, grad_fn=<DivBackward1>)
# tensor(3.3182, grad_fn=<DivBackward1>)
# tensor(3.3450, grad_fn=<DivBackward1>)
# tensor(3.3340, grad_fn=<DivBackward1>)
# tensor(3.3666, grad_fn=<DivBackward1>)
# tensor(3.2954, grad_fn=<DivBackward1>)
# tensor(3.3464, grad_fn=<DivBackward1>)
# tensor(3.3503, grad_fn=<DivBackward1>)
# tensor(3.3680, grad_fn=<DivBackward1>)
# tensor(3.2971, grad_fn=<DivBackward1>)
# tensor(3.3761, grad_fn=<DivBackward1>)
# tensor(3.4052, grad_fn=<DivBackward1>)
# tensor(3.4096, grad_fn=<DivBackward1>)
# tensor(3.3824, grad_fn=<DivBackward1>)
# tensor(3.3518, grad_fn=<DivBackward1>)
# tensor(3.3360, grad_fn=<DivBackward1>)
# tensor(3.3008, grad_fn=<DivBackward1>)
# tensor(3.3375, grad_fn=<DivBackward1>)
# tensor(3.3861, grad_fn=<DivBackward1>)
# tensor(3.3543, grad_fn=<DivBackward1>)
# tensor(3.2376, grad_fn=<DivBackward1>)
# tensor(3.2966, grad_fn=<DivBackward1>)
# tensor(3.3165, grad_fn=<DivBackward1>)
# tensor(3.3293, grad_fn=<DivBackward1>)
# tensor(3.3903, grad_fn=<DivBackward1>)
# tensor(3.4699, grad_fn=<DivBackward1>)
# tensor(3.3673, grad_fn=<DivBackward1>)
# tensor(3.3781, grad_fn=<DivBackward1>)
# tensor(3.3711, grad_fn=<DivBackward1>)
# tensor(3.3108, grad_fn=<DivBackward1>)
# tensor(3.4048, grad_fn=<DivBackward1>)
# tensor(3.3552, grad_fn=<DivBackward1>)
# tensor(3.4468, grad_fn=<DivBackward1>)
# tensor(3.3375, grad_fn=<DivBackward1>)
# tensor(3.2962, grad_fn=<DivBackward1>)
# tensor(3.3136, grad_fn=<DivBackward1>)
# tensor(3.3274, grad_fn=<DivBackward1>)
# tensor(3.3987, grad_fn=<DivBackward1>)
# tensor(3.3600, grad_fn=<DivBackward1>)
# tensor(3.3619, grad_fn=<DivBackward1>)
# tensor(3.3157, grad_fn=<DivBackward1>)
# tensor(3.2595, grad_fn=<DivBackward1>)
# tensor(3.3275, grad_fn=<DivBackward1>)
# tensor(3.3532, grad_fn=<DivBackward1>)
# tensor(3.3403, grad_fn=<DivBackward1>)
# tensor(3.3543, grad_fn=<DivBackward1>)
# tensor(3.3379, grad_fn=<DivBackward1>)
# tensor(3.3100, grad_fn=<DivBackward1>)
# tensor(3.3319, grad_fn=<DivBackward1>)
# tensor(3.3317, grad_fn=<DivBackward1>)
# tensor(3.3042, grad_fn=<DivBackward1>)
# tensor(3.3735, grad_fn=<DivBackward1>)
# tensor(3.3325, grad_fn=<DivBackward1>)
# tensor(3.3280, grad_fn=<DivBackward1>)
# tensor(3.3543, grad_fn=<DivBackward1>)
# tensor(3.3348, grad_fn=<DivBackward1>)
# tensor(3.4027, grad_fn=<DivBackward1>)
# tensor(3.3513, grad_fn=<DivBackward1>)
# tensor(3.3437, grad_fn=<DivBackward1>)
# tensor(3.3592, grad_fn=<DivBackward1>)
# tensor(3.3838, grad_fn=<DivBackward1>)
# tensor(3.3740, grad_fn=<DivBackward1>)
# tensor(3.3555, grad_fn=<DivBackward1>)
# tensor(3.3181, grad_fn=<DivBackward1>)
# tensor(3.3237, grad_fn=<DivBackward1>)
# tensor(3.3485, grad_fn=<DivBackward1>)
# tensor(3.3737, grad_fn=<DivBackward1>)
# tensor(3.3530, grad_fn=<DivBackward1>)
# tensor(3.3406, grad_fn=<DivBackward1>)
# tensor(3.3071, grad_fn=<DivBackward1>)
# tensor(3.3389, grad_fn=<DivBackward1>)
# tensor(3.2287, grad_fn=<DivBackward1>)
# tensor(3.3473, grad_fn=<DivBackward1>)
# tensor(3.3788, grad_fn=<DivBackward1>)
# tensor(3.3372, grad_fn=<DivBackward1>)
# tensor(3.3419, grad_fn=<DivBackward1>)
# tensor(3.3532, grad_fn=<DivBackward1>)
# tensor(3.3415, grad_fn=<DivBackward1>)
# tensor(3.2753, grad_fn=<DivBackward1>)
# tensor(3.3716, grad_fn=<DivBackward1>)
# tensor(3.3405, grad_fn=<DivBackward1>)
# tensor(3.2829, grad_fn=<DivBackward1>)
# tensor(3.3341, grad_fn=<DivBackward1>)
# tensor(3.2594, grad_fn=<DivBackward1>)
# tensor(3.3810, grad_fn=<DivBackward1>)
# tensor(3.3698, grad_fn=<DivBackward1>)
# tensor(3.3310, grad_fn=<DivBackward1>)
# tensor(3.3554, grad_fn=<DivBackward1>)
# tensor(3.3501, grad_fn=<DivBackward1>)
# tensor(3.3253, grad_fn=<DivBackward1>)
# tensor(3.3581, grad_fn=<DivBackward1>)
# tensor(3.3748, grad_fn=<DivBackward1>)
# tensor(3.3733, grad_fn=<DivBackward1>)
# tensor(3.3956, grad_fn=<DivBackward1>)
# tensor(3.3463, grad_fn=<DivBackward1>)
# tensor(3.3529, grad_fn=<DivBackward1>)
# tensor(3.3525, grad_fn=<DivBackward1>)
# tensor(3.3158, grad_fn=<DivBackward1>)
# tensor(3.3232, grad_fn=<DivBackward1>)
# tensor(3.3827, grad_fn=<DivBackward1>)
# tensor(3.4434, grad_fn=<DivBackward1>)
# tensor(3.3658, grad_fn=<DivBackward1>)
# tensor(3.2954, grad_fn=<DivBackward1>)
# tensor(3.3040, grad_fn=<DivBackward1>)
# tensor(3.3383, grad_fn=<DivBackward1>)
# tensor(3.3743, grad_fn=<DivBackward1>)
# tensor(3.3362, grad_fn=<DivBackward1>)
# tensor(3.3779, grad_fn=<DivBackward1>)
# tensor(3.3514, grad_fn=<DivBackward1>)
# tensor(3.3382, grad_fn=<DivBackward1>)
# tensor(3.3522, grad_fn=<DivBackward1>)
# tensor(3.3137, grad_fn=<DivBackward1>)
# tensor(3.3250, grad_fn=<DivBackward1>)
# tensor(3.3654, grad_fn=<DivBackward1>)
# tensor(3.3655, grad_fn=<DivBackward1>)
# tensor(3.3735, grad_fn=<DivBackward1>)
# tensor(3.3885, grad_fn=<DivBackward1>)
# tensor(3.3824, grad_fn=<DivBackward1>)
# tensor(3.4156, grad_fn=<DivBackward1>)
# tensor(3.3351, grad_fn=<DivBackward1>)
# tensor(3.3321, grad_fn=<DivBackward1>)
# tensor(3.4297, grad_fn=<DivBackward1>)
# tensor(3.3255, grad_fn=<DivBackward1>)
# tensor(3.3223, grad_fn=<DivBackward1>)
# tensor(3.3238, grad_fn=<DivBackward1>)
# tensor(3.3377, grad_fn=<DivBackward1>)
# tensor(3.3399, grad_fn=<DivBackward1>)
# tensor(3.3277, grad_fn=<DivBackward1>)
# tensor(3.4026, grad_fn=<DivBackward1>)
# tensor(3.2991, grad_fn=<DivBackward1>)
# tensor(3.3660, grad_fn=<DivBackward1>)
# tensor(3.3538, grad_fn=<DivBackward1>)
# tensor(3.3778, grad_fn=<DivBackward1>)
# tensor(3.3246, grad_fn=<DivBackward1>)
# tensor(3.3379, grad_fn=<DivBackward1>)
# tensor(3.3730, grad_fn=<DivBackward1>)
# tensor(3.3261, grad_fn=<DivBackward1>)
# tensor(3.3083, grad_fn=<DivBackward1>)
# tensor(3.3646, grad_fn=<DivBackward1>)
# tensor(3.3484, grad_fn=<DivBackward1>)
# tensor(3.3764, grad_fn=<DivBackward1>)
# tensor(3.3450, grad_fn=<DivBackward1>)
# tensor(3.1634, grad_fn=<DivBackward1>)
# tensor(3.3960, grad_fn=<DivBackward1>)
# tensor(3.3449, grad_fn=<DivBackward1>)
# tensor(3.2902, grad_fn=<DivBackward1>)
# tensor(3.2993, grad_fn=<DivBackward1>)
# tensor(3.3005, grad_fn=<DivBackward1>)
# tensor(3.3899, grad_fn=<DivBackward1>)
# tensor(3.3066, grad_fn=<DivBackward1>)
# tensor(3.3487, grad_fn=<DivBackward1>)
# tensor(3.3919, grad_fn=<DivBackward1>)
# tensor(3.3604, grad_fn=<DivBackward1>)
# tensor(3.3284, grad_fn=<DivBackward1>)
# tensor(3.3144, grad_fn=<DivBackward1>)
# tensor(3.3304, grad_fn=<DivBackward1>)
# tensor(3.3069, grad_fn=<DivBackward1>)
# tensor(3.3642, grad_fn=<DivBackward1>)
# tensor(3.3148, grad_fn=<DivBackward1>)
# tensor(3.3874, grad_fn=<DivBackward1>)
# tensor(3.3298, grad_fn=<DivBackward1>)
# tensor(3.3440, grad_fn=<DivBackward1>)
# tensor(3.3937, grad_fn=<DivBackward1>)
# tensor(3.3628, grad_fn=<DivBackward1>)
# tensor(3.3528, grad_fn=<DivBackward1>)
# tensor(3.3414, grad_fn=<DivBackward1>)
# tensor(3.3194, grad_fn=<DivBackward1>)
# tensor(3.3391, grad_fn=<DivBackward1>)
# tensor(3.3224, grad_fn=<DivBackward1>)
# tensor(3.3385, grad_fn=<DivBackward1>)
# tensor(3.3467, grad_fn=<DivBackward1>)
# tensor(3.3647, grad_fn=<DivBackward1>)
# tensor(3.3447, grad_fn=<DivBackward1>)
# tensor(3.3699, grad_fn=<DivBackward1>)
# tensor(3.3556, grad_fn=<DivBackward1>)
# tensor(3.3209, grad_fn=<DivBackward1>)
# tensor(3.3945, grad_fn=<DivBackward1>)
# tensor(3.3993, grad_fn=<DivBackward1>)
# tensor(3.3873, grad_fn=<DivBackward1>)
# tensor(3.3841, grad_fn=<DivBackward1>)
# tensor(3.4043, grad_fn=<DivBackward1>)
# tensor(3.4104, grad_fn=<DivBackward1>)
# tensor(3.2833, grad_fn=<DivBackward1>)
# tensor(3.3038, grad_fn=<DivBackward1>)
# tensor(3.2642, grad_fn=<DivBackward1>)
# tensor(3.3343, grad_fn=<DivBackward1>)
# tensor(3.3704, grad_fn=<DivBackward1>)
# tensor(3.4001, grad_fn=<DivBackward1>)
# tensor(3.3823, grad_fn=<DivBackward1>)
# tensor(3.3754, grad_fn=<DivBackward1>)
# tensor(3.3399, grad_fn=<DivBackward1>)
# tensor(3.3620, grad_fn=<DivBackward1>)
# tensor(3.2588, grad_fn=<DivBackward1>)
# tensor(3.3004, grad_fn=<DivBackward1>)
# tensor(3.3423, grad_fn=<DivBackward1>)
# tensor(3.2902, grad_fn=<DivBackward1>)
# tensor(3.3211, grad_fn=<DivBackward1>)
# tensor(3.3717, grad_fn=<DivBackward1>)
# tensor(3.3012, grad_fn=<DivBackward1>)
# tensor(3.3117, grad_fn=<DivBackward1>)
# tensor(3.3097, grad_fn=<DivBackward1>)
# tensor(3.4111, grad_fn=<DivBackward1>)
# tensor(3.3705, grad_fn=<DivBackward1>)
# tensor(3.3925, grad_fn=<DivBackward1>)
# tensor(3.3457, grad_fn=<DivBackward1>)
# tensor(3.3100, grad_fn=<DivBackward1>)
# tensor(3.3257, grad_fn=<DivBackward1>)
# tensor(3.3273, grad_fn=<DivBackward1>)
# tensor(3.3159, grad_fn=<DivBackward1>)
# tensor(3.3761, grad_fn=<DivBackward1>)
# tensor(3.3316, grad_fn=<DivBackward1>)
# tensor(3.2792, grad_fn=<DivBackward1>)
# tensor(3.2983, grad_fn=<DivBackward1>)
# tensor(3.2659, grad_fn=<DivBackward1>)
# tensor(3.3342, grad_fn=<DivBackward1>)
# tensor(3.3506, grad_fn=<DivBackward1>)
# tensor(3.3085, grad_fn=<DivBackward1>)
# tensor(3.3422, grad_fn=<DivBackward1>)
# tensor(3.3581, grad_fn=<DivBackward1>)
# tensor(3.3377, grad_fn=<DivBackward1>)
# tensor(3.3400, grad_fn=<DivBackward1>)
# tensor(3.2538, grad_fn=<DivBackward1>)
# tensor(3.3587, grad_fn=<DivBackward1>)
# tensor(3.2822, grad_fn=<DivBackward1>)
# tensor(3.3892, grad_fn=<DivBackward1>)
# tensor(3.3235, grad_fn=<DivBackward1>)
# tensor(3.3980, grad_fn=<DivBackward1>)
# tensor(3.3132, grad_fn=<DivBackward1>)
# tensor(3.3529, grad_fn=<DivBackward1>)
# tensor(3.2987, grad_fn=<DivBackward1>)
# tensor(3.3764, grad_fn=<DivBackward1>)
# tensor(3.3264, grad_fn=<DivBackward1>)
# tensor(3.3501, grad_fn=<DivBackward1>)
# tensor(3.3622, grad_fn=<DivBackward1>)
# tensor(3.3138, grad_fn=<DivBackward1>)
# tensor(3.3507, grad_fn=<DivBackward1>)
# tensor(3.3393, grad_fn=<DivBackward1>)
# tensor(3.3822, grad_fn=<DivBackward1>)
# tensor(3.3554, grad_fn=<DivBackward1>)
# tensor(3.3139, grad_fn=<DivBackward1>)
# tensor(3.3366, grad_fn=<DivBackward1>)
# tensor(3.3311, grad_fn=<DivBackward1>)
# tensor(3.3175, grad_fn=<DivBackward1>)
# tensor(3.3350, grad_fn=<DivBackward1>)
# tensor(3.3686, grad_fn=<DivBackward1>)
# tensor(3.3437, grad_fn=<DivBackward1>)
# tensor(3.3392, grad_fn=<DivBackward1>)
# tensor(3.3612, grad_fn=<DivBackward1>)
# tensor(3.3866, grad_fn=<DivBackward1>)
# tensor(3.3470, grad_fn=<DivBackward1>)
# tensor(3.3207, grad_fn=<DivBackward1>)
# tensor(3.3539, grad_fn=<DivBackward1>)
# tensor(3.2683, grad_fn=<DivBackward1>)
# tensor(3.3330, grad_fn=<DivBackward1>)
# tensor(3.3330, grad_fn=<DivBackward1>)
# tensor(3.3161, grad_fn=<DivBackward1>)
# tensor(3.3733, grad_fn=<DivBackward1>)
# tensor(3.3833, grad_fn=<DivBackward1>)
# tensor(3.2804, grad_fn=<DivBackward1>)
# tensor(3.4036, grad_fn=<DivBackward1>)
# tensor(3.3899, grad_fn=<DivBackward1>)
# tensor(3.3226, grad_fn=<DivBackward1>)
# tensor(3.4035, grad_fn=<DivBackward1>)
# tensor(3.3674, grad_fn=<DivBackward1>)
# tensor(3.2910, grad_fn=<DivBackward1>)
# tensor(3.3824, grad_fn=<DivBackward1>)
# tensor(3.3048, grad_fn=<DivBackward1>)
# tensor(3.3439, grad_fn=<DivBackward1>)
# tensor(3.4162, grad_fn=<DivBackward1>)
# tensor(3.3431, grad_fn=<DivBackward1>)
# tensor(3.3625, grad_fn=<DivBackward1>)
# tensor(3.3455, grad_fn=<DivBackward1>)
# tensor(3.3692, grad_fn=<DivBackward1>)
# tensor(3.2906, grad_fn=<DivBackward1>)
# tensor(3.3066, grad_fn=<DivBackward1>)
# tensor(3.2982, grad_fn=<DivBackward1>)
# tensor(3.3432, grad_fn=<DivBackward1>)
# tensor(3.3678, grad_fn=<DivBackward1>)
# tensor(3.3657, grad_fn=<DivBackward1>)
# tensor(3.3905, grad_fn=<DivBackward1>)
# tensor(3.2550, grad_fn=<DivBackward1>)
# tensor(3.3177, grad_fn=<DivBackward1>)
# tensor(3.3526, grad_fn=<DivBackward1>)
# tensor(3.3617, grad_fn=<DivBackward1>)
# tensor(3.2832, grad_fn=<DivBackward1>)
# tensor(3.3215, grad_fn=<DivBackward1>)
# tensor(3.2693, grad_fn=<DivBackward1>)
# tensor(3.3472, grad_fn=<DivBackward1>)
# tensor(3.2837, grad_fn=<DivBackward1>)
# tensor(3.3451, grad_fn=<DivBackward1>)
# tensor(3.2866, grad_fn=<DivBackward1>)
# tensor(3.3507, grad_fn=<DivBackward1>)
# tensor(3.3409, grad_fn=<DivBackward1>)
# tensor(3.3231, grad_fn=<DivBackward1>)
# tensor(3.3222, grad_fn=<DivBackward1>)
# tensor(3.3704, grad_fn=<DivBackward1>)
# tensor(3.3131, grad_fn=<DivBackward1>)
# tensor(3.3494, grad_fn=<DivBackward1>)
# tensor(3.3711, grad_fn=<DivBackward1>)
# tensor(3.2632, grad_fn=<DivBackward1>)
# tensor(3.3420, grad_fn=<DivBackward1>)
# tensor(3.3506, grad_fn=<DivBackward1>)
# tensor(3.3271, grad_fn=<DivBackward1>)
# tensor(3.3321, grad_fn=<DivBackward1>)
# tensor(3.3478, grad_fn=<DivBackward1>)
# tensor(3.3379, grad_fn=<DivBackward1>)
# tensor(3.3567, grad_fn=<DivBackward1>)
# tensor(3.2474, grad_fn=<DivBackward1>)
# tensor(3.2910, grad_fn=<DivBackward1>)
# tensor(3.2500, grad_fn=<DivBackward1>)
# tensor(3.3736, grad_fn=<DivBackward1>)
# tensor(3.3874, grad_fn=<DivBackward1>)
# tensor(3.3858, grad_fn=<DivBackward1>)
# tensor(3.3140, grad_fn=<DivBackward1>)
# tensor(3.3631, grad_fn=<DivBackward1>)
# tensor(3.3638, grad_fn=<DivBackward1>)
# tensor(3.3159, grad_fn=<DivBackward1>)
# tensor(3.3849, grad_fn=<DivBackward1>)
# tensor(3.3672, grad_fn=<DivBackward1>)
# tensor(3.3921, grad_fn=<DivBackward1>)
# tensor(3.2188, grad_fn=<DivBackward1>)
# tensor(3.3098, grad_fn=<DivBackward1>)
# tensor(3.3063, grad_fn=<DivBackward1>)
# tensor(3.3995, grad_fn=<DivBackward1>)
# tensor(3.3958, grad_fn=<DivBackward1>)
# tensor(3.3132, grad_fn=<DivBackward1>)
# tensor(3.3211, grad_fn=<DivBackward1>)
# tensor(3.3213, grad_fn=<DivBackward1>)
# tensor(3.4151, grad_fn=<DivBackward1>)
# tensor(3.3248, grad_fn=<DivBackward1>)
# tensor(3.4007, grad_fn=<DivBackward1>)
# tensor(3.3214, grad_fn=<DivBackward1>)
# tensor(3.2518, grad_fn=<DivBackward1>)
# tensor(3.3175, grad_fn=<DivBackward1>)
# tensor(3.2920, grad_fn=<DivBackward1>)
# tensor(3.3464, grad_fn=<DivBackward1>)
# tensor(3.3849, grad_fn=<DivBackward1>)
# tensor(3.3725, grad_fn=<DivBackward1>)
# tensor(3.3344, grad_fn=<DivBackward1>)
# tensor(3.3546, grad_fn=<DivBackward1>)
# tensor(3.3467, grad_fn=<DivBackward1>)
# tensor(3.3161, grad_fn=<DivBackward1>)
# tensor(3.3258, grad_fn=<DivBackward1>)
# tensor(3.3410, grad_fn=<DivBackward1>)
# tensor(3.2706, grad_fn=<DivBackward1>)
# tensor(3.3304, grad_fn=<DivBackward1>)
# tensor(3.3381, grad_fn=<DivBackward1>)
# tensor(3.2862, grad_fn=<DivBackward1>)
# tensor(3.3571, grad_fn=<DivBackward1>)
# tensor(3.3654, grad_fn=<DivBackward1>)
# tensor(3.4124, grad_fn=<DivBackward1>)
# tensor(3.3501, grad_fn=<DivBackward1>)
# tensor(3.3247, grad_fn=<DivBackward1>)
# tensor(3.3106, grad_fn=<DivBackward1>)
# tensor(3.3631, grad_fn=<DivBackward1>)
# tensor(3.4307, grad_fn=<DivBackward1>)
# tensor(3.3243, grad_fn=<DivBackward1>)
# tensor(3.3001, grad_fn=<DivBackward1>)
# tensor(3.3313, grad_fn=<DivBackward1>)
# tensor(3.3422, grad_fn=<DivBackward1>)
# tensor(3.3137, grad_fn=<DivBackward1>)
# tensor(3.3747, grad_fn=<DivBackward1>)
# tensor(3.3166, grad_fn=<DivBackward1>)
# tensor(3.2955, grad_fn=<DivBackward1>)
# tensor(3.3700, grad_fn=<DivBackward1>)
# tensor(3.3166, grad_fn=<DivBackward1>)
# tensor(3.3446, grad_fn=<DivBackward1>)
# tensor(3.3442, grad_fn=<DivBackward1>)
# tensor(3.2944, grad_fn=<DivBackward1>)
# tensor(3.3372, grad_fn=<DivBackward1>)
# tensor(3.3729, grad_fn=<DivBackward1>)
# tensor(3.3387, grad_fn=<DivBackward1>)
# tensor(3.2812, grad_fn=<DivBackward1>)
# tensor(3.3108, grad_fn=<DivBackward1>)
# tensor(3.2858, grad_fn=<DivBackward1>)
# tensor(3.3387, grad_fn=<DivBackward1>)
# tensor(3.3280, grad_fn=<DivBackward1>)
# tensor(3.3229, grad_fn=<DivBackward1>)
# tensor(3.2934, grad_fn=<DivBackward1>)
# tensor(3.3348, grad_fn=<DivBackward1>)
# tensor(3.3012, grad_fn=<DivBackward1>)
# tensor(3.3435, grad_fn=<DivBackward1>)
# tensor(3.3564, grad_fn=<DivBackward1>)
# tensor(3.2824, grad_fn=<DivBackward1>)
# tensor(3.2861, grad_fn=<DivBackward1>)
# tensor(3.3444, grad_fn=<DivBackward1>)
# tensor(3.3710, grad_fn=<DivBackward1>)
# tensor(3.3140, grad_fn=<DivBackward1>)
# tensor(3.3303, grad_fn=<DivBackward1>)
# tensor(3.4007, grad_fn=<DivBackward1>)
# tensor(3.3210, grad_fn=<DivBackward1>)
# tensor(3.3447, grad_fn=<DivBackward1>)
# tensor(3.3717, grad_fn=<DivBackward1>)
# tensor(3.3739, grad_fn=<DivBackward1>)
# tensor(3.3544, grad_fn=<DivBackward1>)
# tensor(3.3557, grad_fn=<DivBackward1>)
# tensor(3.3868, grad_fn=<DivBackward1>)
# tensor(3.3397, grad_fn=<DivBackward1>)
# tensor(3.3411, grad_fn=<DivBackward1>)
# tensor(3.3506, grad_fn=<DivBackward1>)
# tensor(3.3056, grad_fn=<DivBackward1>)
# tensor(3.3586, grad_fn=<DivBackward1>)
# tensor(3.3744, grad_fn=<DivBackward1>)
# tensor(3.3582, grad_fn=<DivBackward1>)
# tensor(3.3454, grad_fn=<DivBackward1>)
# tensor(3.2943, grad_fn=<DivBackward1>)
# tensor(3.3559, grad_fn=<DivBackward1>)
# tensor(3.4208, grad_fn=<DivBackward1>)
# tensor(3.3671, grad_fn=<DivBackward1>)
# tensor(3.3062, grad_fn=<DivBackward1>)
# tensor(3.3794, grad_fn=<DivBackward1>)
# tensor(3.3669, grad_fn=<DivBackward1>)
# tensor(3.3867, grad_fn=<DivBackward1>)
# tensor(3.3033, grad_fn=<DivBackward1>)
# tensor(3.2953, grad_fn=<DivBackward1>)
# tensor(3.3453, grad_fn=<DivBackward1>)
# tensor(3.4101, grad_fn=<DivBackward1>)
# tensor(3.3441, grad_fn=<DivBackward1>)
# tensor(3.3781, grad_fn=<DivBackward1>)
# tensor(3.3314, grad_fn=<DivBackward1>)
# tensor(3.3433, grad_fn=<DivBackward1>)
# tensor(3.3658, grad_fn=<DivBackward1>)
# tensor(3.3760, grad_fn=<DivBackward1>)
# tensor(3.4224, grad_fn=<DivBackward1>)
# tensor(3.3513, grad_fn=<DivBackward1>)
# tensor(3.3809, grad_fn=<DivBackward1>)
# tensor(3.3212, grad_fn=<DivBackward1>)
# tensor(3.3923, grad_fn=<DivBackward1>)
# tensor(3.3780, grad_fn=<DivBackward1>)
# tensor(3.4042, grad_fn=<DivBackward1>)
# tensor(3.3419, grad_fn=<DivBackward1>)
# tensor(3.3849, grad_fn=<DivBackward1>)
# tensor(3.3404, grad_fn=<DivBackward1>)
# tensor(3.3485, grad_fn=<DivBackward1>)
# tensor(3.3397, grad_fn=<DivBackward1>)
# tensor(3.3520, grad_fn=<DivBackward1>)
# tensor(3.3743, grad_fn=<DivBackward1>)
# tensor(3.3203, grad_fn=<DivBackward1>)
# tensor(3.3314, grad_fn=<DivBackward1>)
# tensor(3.3553, grad_fn=<DivBackward1>)
# tensor(3.3307, grad_fn=<DivBackward1>)
# tensor(3.3317, grad_fn=<DivBackward1>)
# tensor(3.3136, grad_fn=<DivBackward1>)
# tensor(3.3971, grad_fn=<DivBackward1>)
# tensor(3.3752, grad_fn=<DivBackward1>)
# tensor(3.3691, grad_fn=<DivBackward1>)
# tensor(3.2929, grad_fn=<DivBackward1>)
# tensor(3.3378, grad_fn=<DivBackward1>)
# tensor(3.3459, grad_fn=<DivBackward1>)
# tensor(3.3686, grad_fn=<DivBackward1>)
# tensor(3.2444, grad_fn=<DivBackward1>)
# tensor(3.4093, grad_fn=<DivBackward1>)
# tensor(3.3362, grad_fn=<DivBackward1>)
# tensor(3.3221, grad_fn=<DivBackward1>)
# tensor(3.3556, grad_fn=<DivBackward1>)
# tensor(3.3776, grad_fn=<DivBackward1>)
# tensor(3.3566, grad_fn=<DivBackward1>)
# tensor(3.3908, grad_fn=<DivBackward1>)
# tensor(3.3422, grad_fn=<DivBackward1>)
# tensor(3.4132, grad_fn=<DivBackward1>)
# tensor(3.4022, grad_fn=<DivBackward1>)
# tensor(3.3266, grad_fn=<DivBackward1>)
# tensor(3.2785, grad_fn=<DivBackward1>)
# tensor(3.3646, grad_fn=<DivBackward1>)
# tensor(3.3580, grad_fn=<DivBackward1>)
# tensor(3.3641, grad_fn=<DivBackward1>)
# tensor(3.3685, grad_fn=<DivBackward1>)
# tensor(3.3244, grad_fn=<DivBackward1>)
# tensor(3.3514, grad_fn=<DivBackward1>)
# tensor(3.3495, grad_fn=<DivBackward1>)
# tensor(3.3089, grad_fn=<DivBackward1>)
# tensor(3.3352, grad_fn=<DivBackward1>)
# tensor(3.2759, grad_fn=<DivBackward1>)
# tensor(3.3548, grad_fn=<DivBackward1>)
# tensor(3.3683, grad_fn=<DivBackward1>)
# tensor(3.3674, grad_fn=<DivBackward1>)
# tensor(3.3331, grad_fn=<DivBackward1>)
# tensor(3.3862, grad_fn=<DivBackward1>)
# tensor(3.3303, grad_fn=<DivBackward1>)
# tensor(3.3475, grad_fn=<DivBackward1>)
# tensor(3.3595, grad_fn=<DivBackward1>)
# tensor(3.3805, grad_fn=<DivBackward1>)
# tensor(3.3517, grad_fn=<DivBackward1>)
# tensor(3.3570, grad_fn=<DivBackward1>)
# tensor(3.3292, grad_fn=<DivBackward1>)
# tensor(3.3669, grad_fn=<DivBackward1>)
# tensor(3.3922, grad_fn=<DivBackward1>)
# tensor(3.3979, grad_fn=<DivBackward1>)
# tensor(3.3877, grad_fn=<DivBackward1>)
# tensor(3.3893, grad_fn=<DivBackward1>)
# tensor(3.4402, grad_fn=<DivBackward1>)
# tensor(3.3748, grad_fn=<DivBackward1>)
# tensor(3.3629, grad_fn=<DivBackward1>)
# tensor(3.3089, grad_fn=<DivBackward1>)
# tensor(3.3063, grad_fn=<DivBackward1>)
# tensor(3.3087, grad_fn=<DivBackward1>)
# tensor(3.3707, grad_fn=<DivBackward1>)
# tensor(3.3083, grad_fn=<DivBackward1>)
# tensor(3.3089, grad_fn=<DivBackward1>)
# tensor(3.3058, grad_fn=<DivBackward1>)
# tensor(3.2711, grad_fn=<DivBackward1>)
# tensor(3.3280, grad_fn=<DivBackward1>)
# tensor(3.3657, grad_fn=<DivBackward1>)
# tensor(3.3570, grad_fn=<DivBackward1>)
# tensor(3.3296, grad_fn=<DivBackward1>)
# tensor(3.3666, grad_fn=<DivBackward1>)
# tensor(3.3375, grad_fn=<DivBackward1>)
# tensor(3.3550, grad_fn=<DivBackward1>)
# tensor(3.3393, grad_fn=<DivBackward1>)
# tensor(3.2823, grad_fn=<DivBackward1>)
# tensor(3.3399, grad_fn=<DivBackward1>)
# tensor(3.2905, grad_fn=<DivBackward1>)
# tensor(3.3500, grad_fn=<DivBackward1>)
# tensor(3.3738, grad_fn=<DivBackward1>)
# tensor(3.3468, grad_fn=<DivBackward1>)
# tensor(3.2915, grad_fn=<DivBackward1>)
# tensor(3.3186, grad_fn=<DivBackward1>)
# tensor(3.3391, grad_fn=<DivBackward1>)
# tensor(3.3232, grad_fn=<DivBackward1>)
# tensor(3.2899, grad_fn=<DivBackward1>)
# tensor(3.3626, grad_fn=<DivBackward1>)
# tensor(3.4146, grad_fn=<DivBackward1>)
# tensor(3.3216, grad_fn=<DivBackward1>)
# tensor(3.3497, grad_fn=<DivBackward1>)
# tensor(3.4070, grad_fn=<DivBackward1>)
# tensor(3.3062, grad_fn=<DivBackward1>)
# tensor(3.4288, grad_fn=<DivBackward1>)
# tensor(3.4090, grad_fn=<DivBackward1>)
# tensor(3.3318, grad_fn=<DivBackward1>)
# tensor(3.3027, grad_fn=<DivBackward1>)
# tensor(3.3645, grad_fn=<DivBackward1>)
# tensor(3.3292, grad_fn=<DivBackward1>)
# tensor(3.3957, grad_fn=<DivBackward1>)
# tensor(3.3174, grad_fn=<DivBackward1>)
# tensor(3.3881, grad_fn=<DivBackward1>)
# tensor(3.3368, grad_fn=<DivBackward1>)
# tensor(3.3828, grad_fn=<DivBackward1>)
# tensor(3.3749, grad_fn=<DivBackward1>)
# tensor(3.3660, grad_fn=<DivBackward1>)
# tensor(3.3237, grad_fn=<DivBackward1>)
# tensor(3.3574, grad_fn=<DivBackward1>)
# tensor(3.2923, grad_fn=<DivBackward1>)
# tensor(3.3120, grad_fn=<DivBackward1>)
# tensor(3.4128, grad_fn=<DivBackward1>)
# tensor(3.3361, grad_fn=<DivBackward1>)
# tensor(3.3589, grad_fn=<DivBackward1>)
# tensor(3.3428, grad_fn=<DivBackward1>)
# tensor(3.3973, grad_fn=<DivBackward1>)
# tensor(3.3674, grad_fn=<DivBackward1>)
# tensor(3.3189, grad_fn=<DivBackward1>)
# tensor(3.2784, grad_fn=<DivBackward1>)
# tensor(3.4201, grad_fn=<DivBackward1>)
# tensor(3.2309, grad_fn=<DivBackward1>)
# tensor(3.3088, grad_fn=<DivBackward1>)
# tensor(3.3941, grad_fn=<DivBackward1>)
# tensor(3.3313, grad_fn=<DivBackward1>)
# tensor(3.3101, grad_fn=<DivBackward1>)
# tensor(3.3419, grad_fn=<DivBackward1>)
# tensor(3.3113, grad_fn=<DivBackward1>)
# tensor(3.3669, grad_fn=<DivBackward1>)
# tensor(3.3554, grad_fn=<DivBackward1>)
# tensor(3.4027, grad_fn=<DivBackward1>)
# tensor(3.3276, grad_fn=<DivBackward1>)
# tensor(3.3853, grad_fn=<DivBackward1>)
# tensor(3.3434, grad_fn=<DivBackward1>)
# tensor(3.3663, grad_fn=<DivBackward1>)
# tensor(3.3167, grad_fn=<DivBackward1>)
# tensor(3.3631, grad_fn=<DivBackward1>)
# tensor(3.3084, grad_fn=<DivBackward1>)
# tensor(3.3520, grad_fn=<DivBackward1>)
# tensor(3.3910, grad_fn=<DivBackward1>)
# tensor(3.3963, grad_fn=<DivBackward1>)
# tensor(3.3589, grad_fn=<DivBackward1>)
# tensor(3.3044, grad_fn=<DivBackward1>)
# tensor(3.3828, grad_fn=<DivBackward1>)
# tensor(3.3512, grad_fn=<DivBackward1>)
# tensor(3.3498, grad_fn=<DivBackward1>)
# tensor(3.3710, grad_fn=<DivBackward1>)
# tensor(3.3576, grad_fn=<DivBackward1>)
# tensor(3.3912, grad_fn=<DivBackward1>)
# tensor(3.3733, grad_fn=<DivBackward1>)
# tensor(3.3377, grad_fn=<DivBackward1>)
# tensor(3.3007, grad_fn=<DivBackward1>)
# tensor(3.3739, grad_fn=<DivBackward1>)
# tensor(3.3533, grad_fn=<DivBackward1>)
# tensor(3.3798, grad_fn=<DivBackward1>)
# tensor(3.4117, grad_fn=<DivBackward1>)
# tensor(3.3459, grad_fn=<DivBackward1>)
# tensor(3.3314, grad_fn=<DivBackward1>)
# tensor(3.3842, grad_fn=<DivBackward1>)
# tensor(3.3015, grad_fn=<DivBackward1>)
# tensor(3.4426, grad_fn=<DivBackward1>)
# tensor(3.3445, grad_fn=<DivBackward1>)
# tensor(3.4152, grad_fn=<DivBackward1>)
# tensor(3.3020, grad_fn=<DivBackward1>)
# tensor(3.3351, grad_fn=<DivBackward1>)
# tensor(3.3323, grad_fn=<DivBackward1>)
# tensor(3.3472, grad_fn=<DivBackward1>)
# tensor(3.3585, grad_fn=<DivBackward1>)
# tensor(3.3677, grad_fn=<DivBackward1>)
# tensor(3.2421, grad_fn=<DivBackward1>)
# tensor(3.3359, grad_fn=<DivBackward1>)
# tensor(3.3915, grad_fn=<DivBackward1>)
# tensor(3.3710, grad_fn=<DivBackward1>)
# tensor(3.3266, grad_fn=<DivBackward1>)
# tensor(3.3305, grad_fn=<DivBackward1>)
# tensor(3.2997, grad_fn=<DivBackward1>)
# tensor(3.3370, grad_fn=<DivBackward1>)
# tensor(3.3944, grad_fn=<DivBackward1>)
# tensor(3.3571, grad_fn=<DivBackward1>)
# tensor(3.3218, grad_fn=<DivBackward1>)
# tensor(3.3835, grad_fn=<DivBackward1>)
# tensor(3.3231, grad_fn=<DivBackward1>)
# tensor(3.2619, grad_fn=<DivBackward1>)
# tensor(3.3193, grad_fn=<DivBackward1>)
# tensor(3.2703, grad_fn=<DivBackward1>)
# tensor(3.3625, grad_fn=<DivBackward1>)
# tensor(3.3222, grad_fn=<DivBackward1>)
# tensor(3.2533, grad_fn=<DivBackward1>)
# tensor(3.3358, grad_fn=<DivBackward1>)
# tensor(3.4004, grad_fn=<DivBackward1>)
# tensor(3.3439, grad_fn=<DivBackward1>)
# tensor(3.3889, grad_fn=<DivBackward1>)
# tensor(3.3737, grad_fn=<DivBackward1>)
# tensor(3.3623, grad_fn=<DivBackward1>)
# tensor(3.3290, grad_fn=<DivBackward1>)
# tensor(3.3992, grad_fn=<DivBackward1>)
# tensor(3.3315, grad_fn=<DivBackward1>)
# tensor(3.3107, grad_fn=<DivBackward1>)
# tensor(3.3294, grad_fn=<DivBackward1>)
# tensor(3.2923, grad_fn=<DivBackward1>)
# tensor(3.3267, grad_fn=<DivBackward1>)
# tensor(3.3783, grad_fn=<DivBackward1>)
# tensor(3.3222, grad_fn=<DivBackward1>)
# tensor(3.3654, grad_fn=<DivBackward1>)
# tensor(3.4006, grad_fn=<DivBackward1>)
# tensor(3.2672, grad_fn=<DivBackward1>)
# tensor(3.3737, grad_fn=<DivBackward1>)
# tensor(3.3517, grad_fn=<DivBackward1>)
# tensor(3.3341, grad_fn=<DivBackward1>)
# tensor(3.3981, grad_fn=<DivBackward1>)
# tensor(3.3581, grad_fn=<DivBackward1>)
# tensor(3.2898, grad_fn=<DivBackward1>)
# tensor(3.3029, grad_fn=<DivBackward1>)
# tensor(3.2989, grad_fn=<DivBackward1>)
# tensor(3.3536, grad_fn=<DivBackward1>)
# tensor(3.3823, grad_fn=<DivBackward1>)
# tensor(3.3771, grad_fn=<DivBackward1>)
# tensor(3.3937, grad_fn=<DivBackward1>)
# tensor(3.3069, grad_fn=<DivBackward1>)
# tensor(3.3620, grad_fn=<DivBackward1>)
# tensor(3.3418, grad_fn=<DivBackward1>)
# tensor(3.3107, grad_fn=<DivBackward1>)
# tensor(3.3053, grad_fn=<DivBackward1>)
# tensor(3.3419, grad_fn=<DivBackward1>)
# tensor(3.3303, grad_fn=<DivBackward1>)
# tensor(3.3353, grad_fn=<DivBackward1>)
# tensor(3.3194, grad_fn=<DivBackward1>)
# tensor(3.3477, grad_fn=<DivBackward1>)
# tensor(3.3947, grad_fn=<DivBackward1>)
# tensor(3.4121, grad_fn=<DivBackward1>)
# tensor(3.3535, grad_fn=<DivBackward1>)
# tensor(3.2681, grad_fn=<DivBackward1>)
# tensor(3.4021, grad_fn=<DivBackward1>)
# tensor(3.3531, grad_fn=<DivBackward1>)
# tensor(3.3504, grad_fn=<DivBackward1>)
# tensor(3.2651, grad_fn=<DivBackward1>)
# tensor(3.3509, grad_fn=<DivBackward1>)
# tensor(3.3639, grad_fn=<DivBackward1>)
# tensor(3.3480, grad_fn=<DivBackward1>)
# tensor(3.3450, grad_fn=<DivBackward1>)
# tensor(3.3142, grad_fn=<DivBackward1>)
# tensor(3.4214, grad_fn=<DivBackward1>)
# tensor(3.3705, grad_fn=<DivBackward1>)
# tensor(3.3266, grad_fn=<DivBackward1>)
# tensor(3.3095, grad_fn=<DivBackward1>)
# tensor(3.3498, grad_fn=<DivBackward1>)
# tensor(3.3593, grad_fn=<DivBackward1>)
# tensor(3.3476, grad_fn=<DivBackward1>)
# tensor(3.3012, grad_fn=<DivBackward1>)
# tensor(3.4058, grad_fn=<DivBackward1>)
# tensor(3.4132, grad_fn=<DivBackward1>)
# tensor(3.3561, grad_fn=<DivBackward1>)
# tensor(3.3747, grad_fn=<DivBackward1>)
# tensor(3.3793, grad_fn=<DivBackward1>)
# tensor(3.3115, grad_fn=<DivBackward1>)
# tensor(3.3407, grad_fn=<DivBackward1>)
# tensor(3.2843, grad_fn=<DivBackward1>)
# tensor(3.3860, grad_fn=<DivBackward1>)
# tensor(3.2991, grad_fn=<DivBackward1>)
# tensor(3.3378, grad_fn=<DivBackward1>)
# tensor(3.2473, grad_fn=<DivBackward1>)
# tensor(3.3228, grad_fn=<DivBackward1>)
# tensor(3.2741, grad_fn=<DivBackward1>)
# tensor(3.3329, grad_fn=<DivBackward1>)
# tensor(3.3162, grad_fn=<DivBackward1>)
# tensor(3.3923, grad_fn=<DivBackward1>)
# tensor(3.3662, grad_fn=<DivBackward1>)
# tensor(3.2951, grad_fn=<DivBackward1>)
# tensor(3.3047, grad_fn=<DivBackward1>)
# tensor(3.3368, grad_fn=<DivBackward1>)
# tensor(3.3695, grad_fn=<DivBackward1>)
# tensor(3.2669, grad_fn=<DivBackward1>)
# tensor(3.3364, grad_fn=<DivBackward1>)
# tensor(3.3412, grad_fn=<DivBackward1>)
# tensor(3.3892, grad_fn=<DivBackward1>)
# tensor(3.2811, grad_fn=<DivBackward1>)
# tensor(3.3265, grad_fn=<DivBackward1>)
# tensor(3.3704, grad_fn=<DivBackward1>)
# tensor(3.3219, grad_fn=<DivBackward1>)
# tensor(3.4068, grad_fn=<DivBackward1>)
# tensor(3.3921, grad_fn=<DivBackward1>)
# tensor(3.2917, grad_fn=<DivBackward1>)
# tensor(3.2706, grad_fn=<DivBackward1>)
# tensor(3.3437, grad_fn=<DivBackward1>)
# tensor(3.3152, grad_fn=<DivBackward1>)
# tensor(3.3122, grad_fn=<DivBackward1>)
# tensor(3.3128, grad_fn=<DivBackward1>)
# tensor(3.3666, grad_fn=<DivBackward1>)
# tensor(3.3724, grad_fn=<DivBackward1>)
# tensor(3.3088, grad_fn=<DivBackward1>)
# tensor(3.3394, grad_fn=<DivBackward1>)
# tensor(3.3865, grad_fn=<DivBackward1>)
# tensor(3.3127, grad_fn=<DivBackward1>)
# tensor(3.4547, grad_fn=<DivBackward1>)
# tensor(3.3151, grad_fn=<DivBackward1>)
# tensor(3.3534, grad_fn=<DivBackward1>)
# tensor(3.3413, grad_fn=<DivBackward1>)
# tensor(3.3637, grad_fn=<DivBackward1>)
# tensor(3.2775, grad_fn=<DivBackward1>)
# tensor(3.3375, grad_fn=<DivBackward1>)
# tensor(3.3606, grad_fn=<DivBackward1>)
# tensor(3.3570, grad_fn=<DivBackward1>)
# tensor(3.3379, grad_fn=<DivBackward1>)
# tensor(3.3706, grad_fn=<DivBackward1>)
# tensor(3.2841, grad_fn=<DivBackward1>)
# tensor(3.3618, grad_fn=<DivBackward1>)
# tensor(3.3509, grad_fn=<DivBackward1>)
# tensor(3.2806, grad_fn=<DivBackward1>)
# tensor(3.3559, grad_fn=<DivBackward1>)
# tensor(3.4461, grad_fn=<DivBackward1>)
# tensor(3.3882, grad_fn=<DivBackward1>)
# tensor(3.3506, grad_fn=<DivBackward1>)
# tensor(3.3474, grad_fn=<DivBackward1>)
# tensor(3.3088, grad_fn=<DivBackward1>)
# tensor(3.3276, grad_fn=<DivBackward1>)
# tensor(3.3497, grad_fn=<DivBackward1>)
# tensor(3.3396, grad_fn=<DivBackward1>)
# tensor(3.3423, grad_fn=<DivBackward1>)
# tensor(3.3669, grad_fn=<DivBackward1>)
# tensor(3.2922, grad_fn=<DivBackward1>)
# tensor(3.3195, grad_fn=<DivBackward1>)
# tensor(3.2783, grad_fn=<DivBackward1>)
# tensor(3.3248, grad_fn=<DivBackward1>)
# tensor(3.3028, grad_fn=<DivBackward1>)
# tensor(3.3356, grad_fn=<DivBackward1>)
# tensor(3.3228, grad_fn=<DivBackward1>)
# tensor(3.2972, grad_fn=<DivBackward1>)
# tensor(3.3024, grad_fn=<DivBackward1>)
# tensor(3.3462, grad_fn=<DivBackward1>)
# tensor(3.3297, grad_fn=<DivBackward1>)
# tensor(3.3181, grad_fn=<DivBackward1>)
# tensor(3.3367, grad_fn=<DivBackward1>)
# tensor(3.2763, grad_fn=<DivBackward1>)
# tensor(3.3026, grad_fn=<DivBackward1>)
# tensor(3.4216, grad_fn=<DivBackward1>)
# tensor(3.3464, grad_fn=<DivBackward1>)
# tensor(3.3546, grad_fn=<DivBackward1>)
# tensor(3.3233, grad_fn=<DivBackward1>)
# tensor(3.3447, grad_fn=<DivBackward1>)
# tensor(3.3224, grad_fn=<DivBackward1>)
# tensor(3.3213, grad_fn=<DivBackward1>)
# tensor(3.3776, grad_fn=<DivBackward1>)
# tensor(3.3473, grad_fn=<DivBackward1>)
# tensor(3.3109, grad_fn=<DivBackward1>)
# tensor(3.3164, grad_fn=<DivBackward1>)
# tensor(3.3132, grad_fn=<DivBackward1>)
# tensor(3.3698, grad_fn=<DivBackward1>)
# tensor(3.4014, grad_fn=<DivBackward1>)
# tensor(3.2746, grad_fn=<DivBackward1>)
# tensor(3.3717, grad_fn=<DivBackward1>)
# tensor(3.3383, grad_fn=<DivBackward1>)
# tensor(3.3616, grad_fn=<DivBackward1>)
# tensor(3.2763, grad_fn=<DivBackward1>)
# tensor(3.3572, grad_fn=<DivBackward1>)
# tensor(3.3815, grad_fn=<DivBackward1>)
# tensor(3.3559, grad_fn=<DivBackward1>)
# tensor(3.3328, grad_fn=<DivBackward1>)
# tensor(3.3050, grad_fn=<DivBackward1>)
# tensor(3.3121, grad_fn=<DivBackward1>)
# tensor(3.3625, grad_fn=<DivBackward1>)
# tensor(3.3551, grad_fn=<DivBackward1>)
# tensor(3.2953, grad_fn=<DivBackward1>)
# tensor(3.3541, grad_fn=<DivBackward1>)
# tensor(3.2851, grad_fn=<DivBackward1>)
# tensor(3.3334, grad_fn=<DivBackward1>)
# tensor(3.3073, grad_fn=<DivBackward1>)
# tensor(3.3586, grad_fn=<DivBackward1>)
# tensor(3.3489, grad_fn=<DivBackward1>)
# tensor(3.3332, grad_fn=<DivBackward1>)
# tensor(3.3542, grad_fn=<DivBackward1>)
# tensor(3.3383, grad_fn=<DivBackward1>)
# tensor(3.3319, grad_fn=<DivBackward1>)
# tensor(3.3279, grad_fn=<DivBackward1>)
# tensor(3.2577, grad_fn=<DivBackward1>)
# tensor(3.3159, grad_fn=<DivBackward1>)
# tensor(3.3669, grad_fn=<DivBackward1>)
# tensor(3.3622, grad_fn=<DivBackward1>)
# tensor(3.3642, grad_fn=<DivBackward1>)
# tensor(3.2758, grad_fn=<DivBackward1>)
# tensor(3.3164, grad_fn=<DivBackward1>)
# tensor(3.2666, grad_fn=<DivBackward1>)
# tensor(3.3178, grad_fn=<DivBackward1>)
# tensor(3.2768, grad_fn=<DivBackward1>)
# tensor(3.3556, grad_fn=<DivBackward1>)
# tensor(3.3382, grad_fn=<DivBackward1>)
# tensor(3.3802, grad_fn=<DivBackward1>)
# tensor(3.2933, grad_fn=<DivBackward1>)
# tensor(3.2998, grad_fn=<DivBackward1>)
# tensor(3.3860, grad_fn=<DivBackward1>)
# tensor(3.2402, grad_fn=<DivBackward1>)
# tensor(3.3636, grad_fn=<DivBackward1>)
# tensor(3.3409, grad_fn=<DivBackward1>)
# tensor(3.3268, grad_fn=<DivBackward1>)
# tensor(3.3345, grad_fn=<DivBackward1>)
# tensor(3.3992, grad_fn=<DivBackward1>)
# tensor(3.3579, grad_fn=<DivBackward1>)
# tensor(3.3056, grad_fn=<DivBackward1>)
# tensor(3.4273, grad_fn=<DivBackward1>)
# tensor(3.3379, grad_fn=<DivBackward1>)
# tensor(3.3743, grad_fn=<DivBackward1>)
# tensor(3.3613, grad_fn=<DivBackward1>)
# tensor(3.3034, grad_fn=<DivBackward1>)
# tensor(3.3267, grad_fn=<DivBackward1>)
# tensor(3.3246, grad_fn=<DivBackward1>)
# tensor(3.4065, grad_fn=<DivBackward1>)
# tensor(3.3553, grad_fn=<DivBackward1>)
# tensor(3.3498, grad_fn=<DivBackward1>)
# tensor(3.3782, grad_fn=<DivBackward1>)
# tensor(3.2847, grad_fn=<DivBackward1>)
# tensor(3.3209, grad_fn=<DivBackward1>)
# tensor(3.3652, grad_fn=<DivBackward1>)
# tensor(3.3482, grad_fn=<DivBackward1>)
# tensor(3.3399, grad_fn=<DivBackward1>)
# tensor(3.3167, grad_fn=<DivBackward1>)
# tensor(3.3988, grad_fn=<DivBackward1>)
# tensor(3.3380, grad_fn=<DivBackward1>)
# tensor(3.3693, grad_fn=<DivBackward1>)
# tensor(3.3227, grad_fn=<DivBackward1>)
# tensor(3.3940, grad_fn=<DivBackward1>)
# tensor(3.3451, grad_fn=<DivBackward1>)
# tensor(3.3437, grad_fn=<DivBackward1>)
# tensor(3.3132, grad_fn=<DivBackward1>)
# tensor(3.2649, grad_fn=<DivBackward1>)
# tensor(3.4022, grad_fn=<DivBackward1>)
# tensor(3.3316, grad_fn=<DivBackward1>)
# tensor(3.3371, grad_fn=<DivBackward1>)
# tensor(3.4592, grad_fn=<DivBackward1>)
# tensor(3.3492, grad_fn=<DivBackward1>)
# tensor(3.3437, grad_fn=<DivBackward1>)
# tensor(3.3312, grad_fn=<DivBackward1>)
# tensor(3.3782, grad_fn=<DivBackward1>)
# tensor(3.2932, grad_fn=<DivBackward1>)
# tensor(3.3782, grad_fn=<DivBackward1>)
# tensor(3.3606, grad_fn=<DivBackward1>)
# tensor(3.3135, grad_fn=<DivBackward1>)
# tensor(3.4151, grad_fn=<DivBackward1>)
# tensor(3.3815, grad_fn=<DivBackward1>)
# tensor(3.3539, grad_fn=<DivBackward1>)
# tensor(3.3598, grad_fn=<DivBackward1>)
# tensor(3.3593, grad_fn=<DivBackward1>)
# tensor(3.3748, grad_fn=<DivBackward1>)
# tensor(3.3364, grad_fn=<DivBackward1>)
# tensor(3.3480, grad_fn=<DivBackward1>)
# tensor(3.3030, grad_fn=<DivBackward1>)
# tensor(3.3885, grad_fn=<DivBackward1>)
# tensor(3.3332, grad_fn=<DivBackward1>)
# tensor(3.2176, grad_fn=<DivBackward1>)
# tensor(3.3070, grad_fn=<DivBackward1>)
# tensor(3.3608, grad_fn=<DivBackward1>)
# tensor(3.3448, grad_fn=<DivBackward1>)
# tensor(3.3514, grad_fn=<DivBackward1>)
# tensor(3.3210, grad_fn=<DivBackward1>)
# tensor(3.3773, grad_fn=<DivBackward1>)
# tensor(3.2831, grad_fn=<DivBackward1>)
# tensor(3.4008, grad_fn=<DivBackward1>)
# tensor(3.3383, grad_fn=<DivBackward1>)
# tensor(3.2834, grad_fn=<DivBackward1>)
# tensor(3.3469, grad_fn=<DivBackward1>)
# tensor(3.3407, grad_fn=<DivBackward1>)
# tensor(3.2968, grad_fn=<DivBackward1>)
# tensor(3.3627, grad_fn=<DivBackward1>)
# tensor(3.3405, grad_fn=<DivBackward1>)
# tensor(3.3199, grad_fn=<DivBackward1>)
# tensor(3.3378, grad_fn=<DivBackward1>)
# tensor(3.3666, grad_fn=<DivBackward1>)
# tensor(3.3719, grad_fn=<DivBackward1>)
# tensor(3.3135, grad_fn=<DivBackward1>)
# tensor(3.2899, grad_fn=<DivBackward1>)
# tensor(3.3076, grad_fn=<DivBackward1>)
# tensor(3.3780, grad_fn=<DivBackward1>)
# tensor(3.3927, grad_fn=<DivBackward1>)
# tensor(3.4071, grad_fn=<DivBackward1>)
# tensor(3.2590, grad_fn=<DivBackward1>)
# tensor(3.3528, grad_fn=<DivBackward1>)
# tensor(3.3461, grad_fn=<DivBackward1>)
# tensor(3.3717, grad_fn=<DivBackward1>)
# tensor(3.3518, grad_fn=<DivBackward1>)
# tensor(3.3520, grad_fn=<DivBackward1>)
# tensor(3.3876, grad_fn=<DivBackward1>)
# tensor(3.3117, grad_fn=<DivBackward1>)
# tensor(3.3401, grad_fn=<DivBackward1>)
# tensor(3.3446, grad_fn=<DivBackward1>)
# tensor(3.3670, grad_fn=<DivBackward1>)
# tensor(3.3162, grad_fn=<DivBackward1>)
# tensor(3.2982, grad_fn=<DivBackward1>)
# tensor(3.3441, grad_fn=<DivBackward1>)
# tensor(3.3330, grad_fn=<DivBackward1>)
# tensor(3.3043, grad_fn=<DivBackward1>)
# tensor(3.2670, grad_fn=<DivBackward1>)
# tensor(3.3237, grad_fn=<DivBackward1>)
# tensor(3.3826, grad_fn=<DivBackward1>)
# tensor(3.3602, grad_fn=<DivBackward1>)
# tensor(3.3022, grad_fn=<DivBackward1>)
# tensor(3.4019, grad_fn=<DivBackward1>)
# tensor(3.3370, grad_fn=<DivBackward1>)
# tensor(3.3819, grad_fn=<DivBackward1>)
# tensor(3.3218, grad_fn=<DivBackward1>)
# tensor(3.3748, grad_fn=<DivBackward1>)
# tensor(3.2932, grad_fn=<DivBackward1>)
# tensor(3.2758, grad_fn=<DivBackward1>)
# tensor(3.3253, grad_fn=<DivBackward1>)
# tensor(3.4106, grad_fn=<DivBackward1>)
# tensor(3.4052, grad_fn=<DivBackward1>)
# tensor(3.3289, grad_fn=<DivBackward1>)
# tensor(3.3743, grad_fn=<DivBackward1>)
# tensor(3.3319, grad_fn=<DivBackward1>)
# tensor(3.2927, grad_fn=<DivBackward1>)
# tensor(3.3768, grad_fn=<DivBackward1>)
# tensor(3.3439, grad_fn=<DivBackward1>)
# tensor(3.3390, grad_fn=<DivBackward1>)
# tensor(3.3945, grad_fn=<DivBackward1>)
# tensor(3.3663, grad_fn=<DivBackward1>)
# tensor(3.3196, grad_fn=<DivBackward1>)
# tensor(3.2666, grad_fn=<DivBackward1>)
# tensor(3.3841, grad_fn=<DivBackward1>)
# tensor(3.3650, grad_fn=<DivBackward1>)
# tensor(3.3740, grad_fn=<DivBackward1>)
# tensor(3.3463, grad_fn=<DivBackward1>)
# tensor(3.3541, grad_fn=<DivBackward1>)
# tensor(3.3149, grad_fn=<DivBackward1>)
# tensor(3.3583, grad_fn=<DivBackward1>)
# tensor(3.3033, grad_fn=<DivBackward1>)
# tensor(3.3581, grad_fn=<DivBackward1>)
# tensor(3.2841, grad_fn=<DivBackward1>)
# tensor(3.3468, grad_fn=<DivBackward1>)
# tensor(3.3691, grad_fn=<DivBackward1>)
# tensor(3.2916, grad_fn=<DivBackward1>)
# tensor(3.3073, grad_fn=<DivBackward1>)
# tensor(3.3217, grad_fn=<DivBackward1>)
# tensor(3.3129, grad_fn=<DivBackward1>)
# tensor(3.3392, grad_fn=<DivBackward1>)
# tensor(3.3420, grad_fn=<DivBackward1>)
# tensor(3.3883, grad_fn=<DivBackward1>)
# tensor(3.3582, grad_fn=<DivBackward1>)
# tensor(3.3056, grad_fn=<DivBackward1>)
# tensor(3.2660, grad_fn=<DivBackward1>)
# tensor(3.3519, grad_fn=<DivBackward1>)
# tensor(3.3228, grad_fn=<DivBackward1>)
# tensor(3.3516, grad_fn=<DivBackward1>)
# tensor(3.3574, grad_fn=<DivBackward1>)
# tensor(3.3283, grad_fn=<DivBackward1>)
# tensor(3.3935, grad_fn=<DivBackward1>)
# tensor(3.3267, grad_fn=<DivBackward1>)
# tensor(3.3099, grad_fn=<DivBackward1>)
# tensor(3.3577, grad_fn=<DivBackward1>)
# tensor(3.3303, grad_fn=<DivBackward1>)
# tensor(3.2821, grad_fn=<DivBackward1>)
# tensor(3.3815, grad_fn=<DivBackward1>)
# tensor(3.3326, grad_fn=<DivBackward1>)
# tensor(3.3020, grad_fn=<DivBackward1>)
# tensor(3.2976, grad_fn=<DivBackward1>)
# tensor(3.3842, grad_fn=<DivBackward1>)
# tensor(3.2861, grad_fn=<DivBackward1>)
# tensor(3.3804, grad_fn=<DivBackward1>)
# tensor(3.3444, grad_fn=<DivBackward1>)
# tensor(3.3951, grad_fn=<DivBackward1>)
# tensor(3.3126, grad_fn=<DivBackward1>)
# tensor(3.3311, grad_fn=<DivBackward1>)
# tensor(3.3510, grad_fn=<DivBackward1>)
# tensor(3.3437, grad_fn=<DivBackward1>)
# tensor(3.3370, grad_fn=<DivBackward1>)
# tensor(3.3887, grad_fn=<DivBackward1>)
# tensor(3.4011, grad_fn=<DivBackward1>)
# tensor(3.3456, grad_fn=<DivBackward1>)
# tensor(3.3706, grad_fn=<DivBackward1>)
# tensor(3.2804, grad_fn=<DivBackward1>)
# tensor(3.4116, grad_fn=<DivBackward1>)
# tensor(3.3493, grad_fn=<DivBackward1>)
# tensor(3.3532, grad_fn=<DivBackward1>)
# tensor(3.3661, grad_fn=<DivBackward1>)
# tensor(3.3946, grad_fn=<DivBackward1>)
# tensor(3.3692, grad_fn=<DivBackward1>)
# tensor(3.3593, grad_fn=<DivBackward1>)
# tensor(3.3193, grad_fn=<DivBackward1>)
# tensor(3.3695, grad_fn=<DivBackward1>)
# tensor(3.3623, grad_fn=<DivBackward1>)
# tensor(3.3811, grad_fn=<DivBackward1>)
# tensor(3.3696, grad_fn=<DivBackward1>)
# tensor(3.3299, grad_fn=<DivBackward1>)
# tensor(3.3161, grad_fn=<DivBackward1>)
# tensor(3.3006, grad_fn=<DivBackward1>)
# tensor(3.3854, grad_fn=<DivBackward1>)
# tensor(3.3522, grad_fn=<DivBackward1>)
# tensor(3.3139, grad_fn=<DivBackward1>)
# tensor(3.3668, grad_fn=<DivBackward1>)
# tensor(3.3291, grad_fn=<DivBackward1>)
# tensor(3.3009, grad_fn=<DivBackward1>)
# tensor(3.3340, grad_fn=<DivBackward1>)
# tensor(3.3554, grad_fn=<DivBackward1>)
# tensor(3.2592, grad_fn=<DivBackward1>)
# tensor(3.3738, grad_fn=<DivBackward1>)
# tensor(3.3246, grad_fn=<DivBackward1>)
# tensor(3.3636, grad_fn=<DivBackward1>)
# tensor(3.3894, grad_fn=<DivBackward1>)
# tensor(3.3461, grad_fn=<DivBackward1>)
# tensor(3.3791, grad_fn=<DivBackward1>)
# tensor(3.3744, grad_fn=<DivBackward1>)
# tensor(3.3922, grad_fn=<DivBackward1>)
# tensor(3.3493, grad_fn=<DivBackward1>)
# tensor(3.3706, grad_fn=<DivBackward1>)
# tensor(3.3363, grad_fn=<DivBackward1>)
# tensor(3.3048, grad_fn=<DivBackward1>)
# tensor(3.2911, grad_fn=<DivBackward1>)
# tensor(3.3766, grad_fn=<DivBackward1>)
# tensor(3.3481, grad_fn=<DivBackward1>)
# tensor(3.3448, grad_fn=<DivBackward1>)
# tensor(3.3972, grad_fn=<DivBackward1>)
# tensor(3.3820, grad_fn=<DivBackward1>)
# tensor(3.3763, grad_fn=<DivBackward1>)
# tensor(3.2914, grad_fn=<DivBackward1>)
# tensor(3.3333, grad_fn=<DivBackward1>)
# tensor(3.3408, grad_fn=<DivBackward1>)
# tensor(3.3200, grad_fn=<DivBackward1>)
# tensor(3.3262, grad_fn=<DivBackward1>)
# tensor(3.3691, grad_fn=<DivBackward1>)
# tensor(3.2786, grad_fn=<DivBackward1>)
# tensor(3.3423, grad_fn=<DivBackward1>)
# tensor(3.3469, grad_fn=<DivBackward1>)
# tensor(3.3482, grad_fn=<DivBackward1>)
# tensor(3.3212, grad_fn=<DivBackward1>)
# tensor(3.3566, grad_fn=<DivBackward1>)
# tensor(3.4074, grad_fn=<DivBackward1>)
# tensor(3.3415, grad_fn=<DivBackward1>)
# tensor(3.3321, grad_fn=<DivBackward1>)
# tensor(3.3378, grad_fn=<DivBackward1>)
# tensor(3.3946, grad_fn=<DivBackward1>)
# tensor(3.3520, grad_fn=<DivBackward1>)
# tensor(3.3380, grad_fn=<DivBackward1>)
# tensor(3.3817, grad_fn=<DivBackward1>)
# tensor(3.3314, grad_fn=<DivBackward1>)
# tensor(3.3426, grad_fn=<DivBackward1>)
# tensor(3.3298, grad_fn=<DivBackward1>)
# tensor(3.3586, grad_fn=<DivBackward1>)
# tensor(3.3939, grad_fn=<DivBackward1>)
# tensor(3.3326, grad_fn=<DivBackward1>)
# tensor(3.2686, grad_fn=<DivBackward1>)
# tensor(3.3170, grad_fn=<DivBackward1>)
# tensor(3.3616, grad_fn=<DivBackward1>)
# tensor(3.3272, grad_fn=<DivBackward1>)
# tensor(3.3018, grad_fn=<DivBackward1>)
# tensor(3.3036, grad_fn=<DivBackward1>)
# tensor(3.1958, grad_fn=<DivBackward1>)
# tensor(3.3941, grad_fn=<DivBackward1>)
# tensor(3.3565, grad_fn=<DivBackward1>)
# tensor(3.3380, grad_fn=<DivBackward1>)
# tensor(3.3421, grad_fn=<DivBackward1>)
# tensor(3.3705, grad_fn=<DivBackward1>)
# tensor(3.2938, grad_fn=<DivBackward1>)
# tensor(3.3002, grad_fn=<DivBackward1>)
# tensor(3.3492, grad_fn=<DivBackward1>)
# tensor(3.3620, grad_fn=<DivBackward1>)
# tensor(3.3106, grad_fn=<DivBackward1>)
# tensor(3.3608, grad_fn=<DivBackward1>)
# tensor(3.3056, grad_fn=<DivBackward1>)
# tensor(3.4015, grad_fn=<DivBackward1>)
# tensor(3.3800, grad_fn=<DivBackward1>)
# tensor(3.2470, grad_fn=<DivBackward1>)
# tensor(3.4132, grad_fn=<DivBackward1>)
# tensor(3.2715, grad_fn=<DivBackward1>)
# tensor(3.3486, grad_fn=<DivBackward1>)
# tensor(3.3641, grad_fn=<DivBackward1>)
# tensor(3.2596, grad_fn=<DivBackward1>)
# tensor(3.3847, grad_fn=<DivBackward1>)
# tensor(3.3715, grad_fn=<DivBackward1>)
# tensor(3.3624, grad_fn=<DivBackward1>)
# tensor(3.2786, grad_fn=<DivBackward1>)
# tensor(3.3809, grad_fn=<DivBackward1>)
# tensor(3.3010, grad_fn=<DivBackward1>)
# tensor(3.3193, grad_fn=<DivBackward1>)
# tensor(3.3637, grad_fn=<DivBackward1>)
# tensor(3.3362, grad_fn=<DivBackward1>)
# tensor(3.3314, grad_fn=<DivBackward1>)
# tensor(3.3267, grad_fn=<DivBackward1>)
# tensor(3.3481, grad_fn=<DivBackward1>)
# tensor(3.3634, grad_fn=<DivBackward1>)
# tensor(3.4180, grad_fn=<DivBackward1>)
# tensor(3.3189, grad_fn=<DivBackward1>)
# tensor(3.3824, grad_fn=<DivBackward1>)
# tensor(3.3362, grad_fn=<DivBackward1>)
# tensor(3.3303, grad_fn=<DivBackward1>)
# tensor(3.3675, grad_fn=<DivBackward1>)
# tensor(3.3723, grad_fn=<DivBackward1>)
# tensor(3.3695, grad_fn=<DivBackward1>)
# tensor(3.3836, grad_fn=<DivBackward1>)
# tensor(3.3916, grad_fn=<DivBackward1>)
# tensor(3.3150, grad_fn=<DivBackward1>)
# tensor(3.3366, grad_fn=<DivBackward1>)
# tensor(3.3122, grad_fn=<DivBackward1>)
# tensor(3.3900, grad_fn=<DivBackward1>)
# tensor(3.3447, grad_fn=<DivBackward1>)
# tensor(3.3479, grad_fn=<DivBackward1>)
# tensor(3.3018, grad_fn=<DivBackward1>)
# tensor(3.3214, grad_fn=<DivBackward1>)
# tensor(3.3472, grad_fn=<DivBackward1>)
# tensor(3.2435, grad_fn=<DivBackward1>)
# ...
# tensor(3.3365, grad_fn=<DivBackward1>)
# tensor(3.3634, grad_fn=<DivBackward1>)
# tensor(3.3045, grad_fn=<DivBackward1>)
# tensor(3.3183, grad_fn=<DivBackward1>)
# tensor(3.3282, grad_fn=<DivBackward1>)
# tensor(3.3485, grad_fn=<DivBackward1>)
# tensor(3.4253, grad_fn=<DivBackward1>)
# tensor(3.3068, grad_fn=<DivBackward1>)
# tensor(3.3521, grad_fn=<DivBackward1>)
# tensor(3.3566, grad_fn=<DivBackward1>)
# tensor(3.3308, grad_fn=<DivBackward1>)
# tensor(3.3566, grad_fn=<DivBackward1>)
# tensor(3.3933, grad_fn=<DivBackward1>)
# tensor(3.3849, grad_fn=<DivBackward1>)
# tensor(3.3239, grad_fn=<DivBackward1>)
# tensor(3.3129, grad_fn=<DivBackward1>)
# tensor(3.4011, grad_fn=<DivBackward1>)
# tensor(3.2883, grad_fn=<DivBackward1>)
# tensor(3.3442, grad_fn=<DivBackward1>)
# tensor(3.3465, grad_fn=<DivBackward1>)
# tensor(3.3376, grad_fn=<DivBackward1>)
# tensor(3.3449, grad_fn=<DivBackward1>)
# tensor(3.3252, grad_fn=<DivBackward1>)
# tensor(3.3988, grad_fn=<DivBackward1>)
# tensor(3.3554, grad_fn=<DivBackward1>)
# tensor(3.3533, grad_fn=<DivBackward1>)
# tensor(3.3889, grad_fn=<DivBackward1>)
# tensor(3.3326, grad_fn=<DivBackward1>)
# tensor(3.3574, grad_fn=<DivBackward1>)
# tensor(3.2571, grad_fn=<DivBackward1>)
# tensor(3.3535, grad_fn=<DivBackward1>)
# tensor(3.3499, grad_fn=<DivBackward1>)
# tensor(3.3078, grad_fn=<DivBackward1>)
# tensor(3.3004, grad_fn=<DivBackward1>)
# tensor(3.3362, grad_fn=<DivBackward1>)
# tensor(3.4013, grad_fn=<DivBackward1>)
# tensor(3.3411, grad_fn=<DivBackward1>)
# tensor(3.2722, grad_fn=<DivBackward1>)
# tensor(3.2866, grad_fn=<DivBackward1>)
# tensor(3.2879, grad_fn=<DivBackward1>)
# tensor(3.2921, grad_fn=<DivBackward1>)
# tensor(3.3274, grad_fn=<DivBackward1>)
# tensor(3.3334, grad_fn=<DivBackward1>)
# tensor(3.3159, grad_fn=<DivBackward1>)
# tensor(3.3507, grad_fn=<DivBackward1>)
# tensor(3.3425, grad_fn=<DivBackward1>)
# tensor(3.3828, grad_fn=<DivBackward1>)
# tensor(3.2582, grad_fn=<DivBackward1>)
# tensor(3.3605, grad_fn=<DivBackward1>)
# tensor(3.3387, grad_fn=<DivBackward1>)
# tensor(3.3411, grad_fn=<DivBackward1>)
# tensor(3.2979, grad_fn=<DivBackward1>)
# tensor(3.3152, grad_fn=<DivBackward1>)
# tensor(3.2852, grad_fn=<DivBackward1>)
# tensor(3.3163, grad_fn=<DivBackward1>)
# tensor(3.3853, grad_fn=<DivBackward1>)
# tensor(3.3404, grad_fn=<DivBackward1>)
# tensor(3.3357, grad_fn=<DivBackward1>)
# tensor(3.3276, grad_fn=<DivBackward1>)
# tensor(3.3163, grad_fn=<DivBackward1>)
# tensor(3.3491, grad_fn=<DivBackward1>)
# tensor(3.3060, grad_fn=<DivBackward1>)
# tensor(3.3884, grad_fn=<DivBackward1>)
# tensor(3.3302, grad_fn=<DivBackward1>)
# tensor(3.3484, grad_fn=<DivBackward1>)
# tensor(3.3861, grad_fn=<DivBackward1>)
# tensor(3.3533, grad_fn=<DivBackward1>)
# tensor(3.2103, grad_fn=<DivBackward1>)
# tensor(3.3759, grad_fn=<DivBackward1>)
# tensor(3.3790, grad_fn=<DivBackward1>)
# tensor(3.3741, grad_fn=<DivBackward1>)
# tensor(3.3275, grad_fn=<DivBackward1>)
# tensor(3.3433, grad_fn=<DivBackward1>)
# tensor(3.3777, grad_fn=<DivBackward1>)
# tensor(3.3257, grad_fn=<DivBackward1>)
# tensor(3.3747, grad_fn=<DivBackward1>)
# tensor(3.3115, grad_fn=<DivBackward1>)
# tensor(3.3119, grad_fn=<DivBackward1>)
# tensor(3.3590, grad_fn=<DivBackward1>)
# tensor(3.2874, grad_fn=<DivBackward1>)
# tensor(3.2748, grad_fn=<DivBackward1>)
# tensor(3.3317, grad_fn=<DivBackward1>)
# tensor(3.3466, grad_fn=<DivBackward1>)
# tensor(3.3107, grad_fn=<DivBackward1>)
# tensor(3.3453, grad_fn=<DivBackward1>)
# tensor(3.2544, grad_fn=<DivBackward1>)
# tensor(3.3523, grad_fn=<DivBackward1>)
# tensor(3.3734, grad_fn=<DivBackward1>)
# tensor(3.3218, grad_fn=<DivBackward1>)
# tensor(3.3136, grad_fn=<DivBackward1>)
# tensor(3.2978, grad_fn=<DivBackward1>)
# tensor(3.2863, grad_fn=<DivBackward1>)
# tensor(3.3926, grad_fn=<DivBackward1>)
# tensor(3.4059, grad_fn=<DivBackward1>)
# tensor(3.4211, grad_fn=<DivBackward1>)
# tensor(3.3697, grad_fn=<DivBackward1>)
# tensor(3.3580, grad_fn=<DivBackward1>)
# tensor(3.3634, grad_fn=<DivBackward1>)
# tensor(3.3454, grad_fn=<DivBackward1>)
# tensor(3.3229, grad_fn=<DivBackward1>)
# tensor(3.3466, grad_fn=<DivBackward1>)
# tensor(3.3499, grad_fn=<DivBackward1>)
# tensor(3.3380, grad_fn=<DivBackward1>)
# tensor(3.3325, grad_fn=<DivBackward1>)
# tensor(3.3476, grad_fn=<DivBackward1>)
# tensor(3.3863, grad_fn=<DivBackward1>)
# tensor(3.3877, grad_fn=<DivBackward1>)
# tensor(3.3709, grad_fn=<DivBackward1>)
# tensor(3.3233, grad_fn=<DivBackward1>)
# tensor(3.3360, grad_fn=<DivBackward1>)
# tensor(3.4121, grad_fn=<DivBackward1>)
# tensor(3.2556, grad_fn=<DivBackward1>)
# tensor(3.3213, grad_fn=<DivBackward1>)
# tensor(3.3466, grad_fn=<DivBackward1>)
# tensor(3.3929, grad_fn=<DivBackward1>)
# tensor(3.3283, grad_fn=<DivBackward1>)
# tensor(3.3468, grad_fn=<DivBackward1>)
# tensor(3.3026, grad_fn=<DivBackward1>)
# tensor(3.3276, grad_fn=<DivBackward1>)
# tensor(3.3690, grad_fn=<DivBackward1>)
# tensor(3.3346, grad_fn=<DivBackward1>)
# tensor(3.2150, grad_fn=<DivBackward1>)
# tensor(3.3617, grad_fn=<DivBackward1>)
# tensor(3.3365, grad_fn=<DivBackward1>)
# tensor(3.3565, grad_fn=<DivBackward1>)
# tensor(3.3254, grad_fn=<DivBackward1>)
# tensor(3.3865, grad_fn=<DivBackward1>)
# tensor(3.2974, grad_fn=<DivBackward1>)
# tensor(3.3903, grad_fn=<DivBackward1>)
# tensor(3.3878, grad_fn=<DivBackward1>)
# tensor(3.3417, grad_fn=<DivBackward1>)
# tensor(3.3816, grad_fn=<DivBackward1>)
# tensor(3.3639, grad_fn=<DivBackward1>)
# tensor(3.2617, grad_fn=<DivBackward1>)
# tensor(3.2213, grad_fn=<DivBackward1>)
# tensor(3.3819, grad_fn=<DivBackward1>)
# tensor(3.3474, grad_fn=<DivBackward1>)
# tensor(3.3673, grad_fn=<DivBackward1>)
# tensor(3.3888, grad_fn=<DivBackward1>)
# tensor(3.3716, grad_fn=<DivBackward1>)
# tensor(3.3518, grad_fn=<DivBackward1>)
# tensor(3.3611, grad_fn=<DivBackward1>)
# tensor(3.2974, grad_fn=<DivBackward1>)
# tensor(3.3616, grad_fn=<DivBackward1>)
# tensor(3.3515, grad_fn=<DivBackward1>)
# tensor(3.3259, grad_fn=<DivBackward1>)
# tensor(3.3465, grad_fn=<DivBackward1>)
# tensor(3.3929, grad_fn=<DivBackward1>)
# tensor(3.3449, grad_fn=<DivBackward1>)
# tensor(3.4122, grad_fn=<DivBackward1>)
# tensor(3.3072, grad_fn=<DivBackward1>)
# tensor(3.3765, grad_fn=<DivBackward1>)
# tensor(3.3709, grad_fn=<DivBackward1>)
# tensor(3.3548, grad_fn=<DivBackward1>)
# tensor(3.2845, grad_fn=<DivBackward1>)
# tensor(3.3642, grad_fn=<DivBackward1>)
# tensor(3.3417, grad_fn=<DivBackward1>)
# tensor(3.3240, grad_fn=<DivBackward1>)
# tensor(3.3361, grad_fn=<DivBackward1>)
# tensor(3.3409, grad_fn=<DivBackward1>)
# tensor(3.3613, grad_fn=<DivBackward1>)
# tensor(3.3316, grad_fn=<DivBackward1>)
# tensor(3.3414, grad_fn=<DivBackward1>)
# tensor(3.3104, grad_fn=<DivBackward1>)
# tensor(3.3472, grad_fn=<DivBackward1>)
# tensor(3.2959, grad_fn=<DivBackward1>)
# tensor(3.3467, grad_fn=<DivBackward1>)
# tensor(3.3114, grad_fn=<DivBackward1>)
# tensor(3.3372, grad_fn=<DivBackward1>)
# tensor(3.3123, grad_fn=<DivBackward1>)
# tensor(3.3356, grad_fn=<DivBackward1>)
# tensor(3.3198, grad_fn=<DivBackward1>)
# tensor(3.3276, grad_fn=<DivBackward1>)
# tensor(3.3978, grad_fn=<DivBackward1>)
# tensor(3.3160, grad_fn=<DivBackward1>)
# tensor(3.2829, grad_fn=<DivBackward1>)
# tensor(3.3109, grad_fn=<DivBackward1>)
# tensor(3.4006, grad_fn=<DivBackward1>)
# tensor(3.3433, grad_fn=<DivBackward1>)
# tensor(3.3920, grad_fn=<DivBackward1>)
# tensor(3.3212, grad_fn=<DivBackward1>)
# tensor(3.4037, grad_fn=<DivBackward1>)
# tensor(3.3215, grad_fn=<DivBackward1>)
# tensor(3.4120, grad_fn=<DivBackward1>)
# tensor(3.3919, grad_fn=<DivBackward1>)
# tensor(3.3051, grad_fn=<DivBackward1>)
# tensor(3.3963, grad_fn=<DivBackward1>)
# tensor(3.3417, grad_fn=<DivBackward1>)
# tensor(3.3459, grad_fn=<DivBackward1>)
# tensor(3.4179, grad_fn=<DivBackward1>)
# tensor(3.2685, grad_fn=<DivBackward1>)
# tensor(3.3392, grad_fn=<DivBackward1>)
# tensor(3.3361, grad_fn=<DivBackward1>)
# tensor(3.3332, grad_fn=<DivBackward1>)
# tensor(3.2598, grad_fn=<DivBackward1>)
# tensor(3.3517, grad_fn=<DivBackward1>)
# tensor(3.3717, grad_fn=<DivBackward1>)
# tensor(3.3070, grad_fn=<DivBackward1>)
# tensor(3.3891, grad_fn=<DivBackward1>)
# tensor(3.3182, grad_fn=<DivBackward1>)
# tensor(3.3681, grad_fn=<DivBackward1>)
# tensor(3.2770, grad_fn=<DivBackward1>)
# tensor(3.3974, grad_fn=<DivBackward1>)
# tensor(3.3303, grad_fn=<DivBackward1>)
# tensor(3.3117, grad_fn=<DivBackward1>)
# tensor(3.2615, grad_fn=<DivBackward1>)
# tensor(3.3203, grad_fn=<DivBackward1>)
# tensor(3.3386, grad_fn=<DivBackward1>)
# tensor(3.3943, grad_fn=<DivBackward1>)
# tensor(3.3507, grad_fn=<DivBackward1>)
# tensor(3.3317, grad_fn=<DivBackward1>)
# tensor(3.3597, grad_fn=<DivBackward1>)
# tensor(3.3184, grad_fn=<DivBackward1>)
# tensor(3.3705, grad_fn=<DivBackward1>)
# tensor(3.3172, grad_fn=<DivBackward1>)
# tensor(3.3368, grad_fn=<DivBackward1>)
# tensor(3.3480, grad_fn=<DivBackward1>)
# tensor(3.3822, grad_fn=<DivBackward1>)
# tensor(3.3477, grad_fn=<DivBackward1>)
# tensor(3.3297, grad_fn=<DivBackward1>)
# tensor(3.3009, grad_fn=<DivBackward1>)
# tensor(3.3302, grad_fn=<DivBackward1>)
# tensor(3.3027, grad_fn=<DivBackward1>)
# tensor(3.3881, grad_fn=<DivBackward1>)
# tensor(3.3865, grad_fn=<DivBackward1>)
# tensor(3.3640, grad_fn=<DivBackward1>)
# tensor(3.3143, grad_fn=<DivBackward1>)
# tensor(3.3347, grad_fn=<DivBackward1>)
# tensor(3.3225, grad_fn=<DivBackward1>)
# tensor(3.4205, grad_fn=<DivBackward1>)
# tensor(3.4009, grad_fn=<DivBackward1>)
# tensor(3.3472, grad_fn=<DivBackward1>)
# tensor(3.3246, grad_fn=<DivBackward1>)
# tensor(3.3759, grad_fn=<DivBackward1>)
# tensor(3.3122, grad_fn=<DivBackward1>)
# tensor(3.4203, grad_fn=<DivBackward1>)
# tensor(3.2730, grad_fn=<DivBackward1>)
# tensor(3.4220, grad_fn=<DivBackward1>)
# tensor(3.3567, grad_fn=<DivBackward1>)
# tensor(3.3837, grad_fn=<DivBackward1>)
# tensor(3.4316, grad_fn=<DivBackward1>)
# tensor(3.3522, grad_fn=<DivBackward1>)
# tensor(3.3736, grad_fn=<DivBackward1>)
# tensor(3.2589, grad_fn=<DivBackward1>)
# tensor(3.3449, grad_fn=<DivBackward1>)
# tensor(3.1321, grad_fn=<DivBackward1>)
# tensor(3.3397, grad_fn=<DivBackward1>)
# tensor(3.3277, grad_fn=<DivBackward1>)
# tensor(3.4049, grad_fn=<DivBackward1>)
# tensor(3.3970, grad_fn=<DivBackward1>)
# tensor(3.3790, grad_fn=<DivBackward1>)
# tensor(3.3772, grad_fn=<DivBackward1>)
# tensor(3.2798, grad_fn=<DivBackward1>)
# tensor(3.3955, grad_fn=<DivBackward1>)
# tensor(3.3651, grad_fn=<DivBackward1>)
# tensor(3.2935, grad_fn=<DivBackward1>)
# tensor(3.3303, grad_fn=<DivBackward1>)
# tensor(3.3920, grad_fn=<DivBackward1>)
# tensor(3.2686, grad_fn=<DivBackward1>)
# tensor(3.3202, grad_fn=<DivBackward1>)
# tensor(3.2475, grad_fn=<DivBackward1>)
# tensor(3.3416, grad_fn=<DivBackward1>)
# tensor(3.3320, grad_fn=<DivBackward1>)
# tensor(3.3787, grad_fn=<DivBackward1>)
# tensor(3.3588, grad_fn=<DivBackward1>)
# tensor(3.3681, grad_fn=<DivBackward1>)
# tensor(3.3416, grad_fn=<DivBackward1>)
# tensor(3.3281, grad_fn=<DivBackward1>)
# tensor(3.3515, grad_fn=<DivBackward1>)
# tensor(3.3804, grad_fn=<DivBackward1>)
# tensor(3.3471, grad_fn=<DivBackward1>)
# tensor(3.3326, grad_fn=<DivBackward1>)
# tensor(3.2656, grad_fn=<DivBackward1>)
# tensor(3.3735, grad_fn=<DivBackward1>)
# tensor(3.2334, grad_fn=<DivBackward1>)
# tensor(3.2580, grad_fn=<DivBackward1>)
# tensor(3.4172, grad_fn=<DivBackward1>)
# tensor(3.2938, grad_fn=<DivBackward1>)
# tensor(3.3661, grad_fn=<DivBackward1>)
# tensor(3.3736, grad_fn=<DivBackward1>)
# tensor(3.3114, grad_fn=<DivBackward1>)
# tensor(3.4457, grad_fn=<DivBackward1>)
# tensor(3.3466, grad_fn=<DivBackward1>)
# tensor(3.2824, grad_fn=<DivBackward1>)
# tensor(3.3485, grad_fn=<DivBackward1>)
# tensor(3.3323, grad_fn=<DivBackward1>)
# tensor(3.3866, grad_fn=<DivBackward1>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 14
#      11 i += 1
#      13 other_player = HangmanPlayer(word, lstm)
# ---> 14 words_seen, previous_letters, correct_responses = other_player.run()
#      16 # output = lstm(words_seen,  previous_letters)
#      19 optimizer.zero_grad()
#
# Cell In[10], line 79, in HangmanPlayer.run(self)
#      76 self.encoded_previous_guesses = torch.tensor(self.encode_previous_guesses())
#      77 self.encoded_previous_guesses = torch.reshape(self.encoded_previous_guesses, [1, self.encoded_previous_guesses.shape[0]])
# ---> 79 output = torch.squeeze(self.z(self.encoded_obscured_word, self.encoded_previous_guesses))
#      80 guess = torch.argmax(output)
#      81 attempt = 2
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[11], line 10, in LSTMNet.forward(self, input_obscured_word_seen, input_letters_guessed_previously)
#       8 def forward(self, input_obscured_word_seen, input_letters_guessed_previously):
# ---> 10     lstm_outputs, _ = self.lstm(input_obscured_word_seen)
#      11     final_lstm_output = lstm_outputs[:, -1, : ]
#      13     combined_input = torch.cat((final_lstm_output, input_letters_guessed_previously), dim=1)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/rnn.py:812, in LSTM.forward(self, input, hx)
#     810 self.check_forward_args(input, hx, batch_sizes)
#     811 if batch_sizes is None:
# --> 812     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     813                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     814 else:
#     815     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     816                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# File ~/.local/lib/python3.8/site-packages/torch/fx/traceback.py:41, in format_stack()
#      38     return [current_meta.get("stack_trace", "")]
#      39 else:
#      40     # fallback to traceback.format_stack()
# ---> 41     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File /usr/lib/python3.8/traceback.py:211, in extract_stack(f, limit)
#     209 if f is None:
#     210     f = sys._getframe().f_back
# --> 211 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212 stack.reverse()
#     213 return stack
#
# File /usr/lib/python3.8/traceback.py:359, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     357     else:
#     358         f_locals = None
# --> 359     result.append(FrameSummary(
#     360         filename, lineno, name, lookup_line=False, locals=f_locals))
#     361 for filename in fnames:
#     362     linecache.checkcache(filename)
#
# File /usr/lib/python3.8/traceback.py:243, in FrameSummary.__init__(self, filename, lineno, name, lookup_line, locals, line)
#     228 """A single frame from a traceback.
#     229
#     230 - :attr:`filename` The filename for the frame.
#    (...)
#     238   mapping the name to the repr() of the variable.
#     239 """
#     241 __slots__ = ('filename', 'lineno', 'name', '_line', 'locals')
# --> 243 def __init__(self, filename, lineno, name, *, lookup_line=True,
#     244         locals=None, line=None):
#     245     """Construct a FrameSummary.
#     246
#     247     :param lookup_line: If True, `linecache` is consulted for the source
#    (...)
#     252         the linecache.
#     253     """
#     254     self.filename = filename
#
# KeyboardInterrupt:

# %%
torch.Size([6, 12, 27]) torch.Size([6, 26])

# %%
MAX_NUM_INPUTS
# Out:
# 28

# %%
lstm = nn.LSTM(27, MAX_NUM_INPUTS)
fc = nn.Linear(MAX_NUM_INPUTS + 26, 26)
input_obscured_word_seen = words_seen
input_letters_guessed_previously = previous_letters

# %%
lstm_outputs, _ = lstm(input_obscured_word_seen)
lstm_outputs.shape
# Out:
# torch.Size([6, 12, 28])

# %%
final_lstm_output = lstm_outputs[:, -1, : ]
final_lstm_output.shape
# Out:
# torch.Size([6, 28])

# %%
combined_input = torch.cat((final_lstm_output, input_letters_guessed_previously), dim=1)
combined_input.shape
# Out:
# torch.Size([6, 54])

# %%
output = fc(combined_input)

# %%
output.shape
# Out:
# torch.Size([6, 26])

# %%
# encoded word after guess not changing check the tensor to numpy thing
